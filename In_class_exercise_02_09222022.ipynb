# %% [markdown]
# <a href="https://colab.research.google.com/github/sridhar-maddi/Sridhar_INFO5731_FALL2022/blob/main/In_class_exercise_02_09222022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The second In-class-exercise (09/22/2022, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:
I bought an iphone from indian e-commerce website in India.I want to collect the reviews of the phone.
To get this data, I have used two Python libraries - BeautifulSoup and Requests. I have written the steps I have did to collect the data
 I have taken the for loop to iterate it through all the pages and to  get the required page, I have used requests Pyhthon library.
 I have used beautiful soup to collect the data and used the inspect element to find out the class names for the title of the reviews and for the full text.
 To display the data, I have used data frame. 





'''

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):

from bs4 import BeautifulSoup
import requests
import pandas
title = []
fullReview =[]
for i in range(70):
  URL = "https://www.flipkart.com/apple-iphone-11-white-64-gb/product-reviews/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&lid=LSTMOBFWQ6BVWVEH3XESAHPTP&marketplace=FLIPKART&page=" + str(i)
  webPage = requests.get(URL) 
  beautifulSoup = BeautifulSoup(webPage.text, 'html.parser')
  title_text = beautifulSoup.find_all(class_='_2-N8zT') 
  fullReview_text = beautifulSoup.find_all(class_='t-ZTKy') 
  for ele1, ele2 in zip(title_text, fullReview_text): 
      title.append(ele1.text) 
      fullReview.append(ele2.text)
res = pandas.DataFrame(list(zip(title, fullReview)), columns =['Title of the review', 'Full text review']) 
res
# Out:
#      Title of the review                                   Full text review
# 0         Simply awesome  Really satisfied with the Product I received.....
# 1       Perfect product!  Amazing phone with great cameras and better ba...
# 2    Best in the market!  Great iPhone very snappy experience as apple k...
# 3      Worth every penny  Previously I was using one plus 3t it was a gr...
# 4     Highly recommended  What a camera .....just awesome ..you can feel...
# ..                   ...                                                ...
# 573            Wonderful  It’s beautiful and budgeted too happy with fli...
# 574               Super!                            Always awesomeREAD MORE
# 575            Brilliant  Trust me on this I was worried about the selle...
# 576             Terrific  My first flagship mobile...it’s completely wor...
# 577   Highly recommended         East or west iphone is the best 😂READ MORE
#
# [578 rows x 2 columns]

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2012-2022).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
# You code here (Please add comments in the code):
import json as js
import urllib.request as request
from bs4 import BeautifulSoup as cast

with request.urlopen('https://api.semanticscholar.org/v1/paper/10.1145/2348283.2348407') as uliweb:
    pg = uliweb.read()
    s = cast(pg)
    print(s.p.text)
    with open('output.txt', 'w') as textsum:
        j.dump(s.p.text, textsum)
# Out:
# {"abstract":"Typically, every part in most coherent text has some plausible reason for its presence, some function that it performs to the overall semantics of the text. Rhetorical relations, e.g. contrast, cause, explanation, describe how the parts of a text are linked to each other. Knowledge about this so-called discourse structure has been applied successfully to several natural language processing tasks. This work studies the use of rhetorical relations for Information Retrieval (IR): Is there a correlation between certain rhetorical relations and retrieval performance? Can knowledge about a document's rhetorical relations be useful to IR? We present a language model modification that considers rhetorical relations when estimating the relevance of a document to a query. Empirical evaluation of different versions of our model on TREC settings shows that certain rhetorical relations can benefit retrieval effectiveness notably (>10% in mean average precision over a state-of-the-art
# ...

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
import os
import tweepy as tw
import pandas as pd

key= 'cIMg0BPU6KFmNVaS2ESrpTbXQ'
secret= '6x7eF9PYLW443kjSJYtbCGfJrKwBmyPzSOqG0jQKkb8qzY3hK6'
token= '1573330815995502592-fIoOKJ33IXvNIzAmWdIRnU42wX6tmH'
access_secret= 'DNLEJHQM96si7fYulKPoBkpwJ4LrHkMMezI8aOK2CH4Xq'

authorize = tw.OAuthHandler(key, secret)
authorize.set_access_token(token, access_secret)
api = tw.API(authorize, wait_on_rate_limit=True)

key_word = "#actors"
required_date_from = "2022-09-22"

tweets = tw.Cursor(api.search,
              q=key_word,
              lang="en",
              since=required_date_from).items(1000)

[tweet.text for tweet in tweets]
# Out:
# ['@RobertDowneyJr which one do you want? #actor #actors #handdrawn https://t.co/qt0SkLdNSZ',
#  'RT @herman_johansen: Table read. Meet and greet. #Rehearsal day one...\n#actorsstudio66 #theatre #directorslife #actors #NewMexico https://t…',
#  'Good morning, Have a great  , everyone! # #thetv360 #style #ayezakhan #model #photography #arydigital #celebrities… https://t.co/10Qb6o6dwa',
#  'No News Is Still Good News, so Let’s Dive Into Season 5 Fan Theories &gt;&gt; READ MORE https://t.co/F7iFRPE6Z7 &lt;&lt;… https://t.co/nLMxmvgDox',
#  'Review: “The Adam Project – Dark Horizons &gt;&gt; READ MORE https://t.co/5d3GUsxNiQ &lt;&lt; #movies #movie #film #films… https://t.co/AJTZcDWAkX',
#  '#devanand #Birthanniversary #actors #filmIndustry\n\n💼 Connect With Us : *KASAUDHAN MEDICAL STORE*\n\n📞 Call : 90444746… https://t.co/hYDJrB0l1u',
#  '#SurveyJunkie - Take Online Surveys for Cash Rewards, Vouchers &amp; More.\n\nRetweet To Enter: https://t.co/IiTHjxMV6z… https://t.co/DxJTl6Boia',
# ...
