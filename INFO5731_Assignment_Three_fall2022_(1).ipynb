# %% [markdown]
# <a href="https://colab.research.google.com/github/sridhar-maddi/Sridhar_INFO5731_FALL2022/blob/main/INFO5731_Assignment_Three_fall2022_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
# Write your code here
#installing selenium package
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3,066 kB]
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,494 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,561 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1,303 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [29.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,336 kB]
# Get:20 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [2,225 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [1,138 kB]
# Fetched 15.4 MB in 4s (3,461 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 7 not upgraded.
# Need to get 95.1 MB of archives.
# After this operation, 319 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 107.0.5304.87-0ubuntu11.18.04.1 [1,158 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 107.0.5304.87-0ubuntu11.18.04.1 [83.1 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 107.0.5304.87-0ubuntu11.18.04.1 [5,260 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 107.0.5304.87-0ubuntu11.18.04.1 [5,570 kB]
# Fetched 95.1 MB in 6s (15.2 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 123991 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_107.0.5304.87-0ubuntu11.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (107.0.5304.87-0ubuntu11.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_107.0.5304.87-0ubuntu11.18.04.1_amd64.deb ...
# Unpacking chromium-browser (107.0.5304.87-0ubuntu11.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_107.0.5304.87-0ubuntu11.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (107.0.5304.87-0ubuntu11.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_107.0.5304.87-0ubuntu11.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (107.0.5304.87-0ubuntu11.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (107.0.5304.87-0ubuntu11.18.04.1) ...
# Setting up chromium-browser (107.0.5304.87-0ubuntu11.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (107.0.5304.87-0ubuntu11.18.04.1) ...
# Setting up chromium-browser-l10n (107.0.5304.87-0ubuntu11.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting selenium
#   Downloading selenium-4.6.0-py3-none-any.whl (5.2 MB)
#      |████████████████████████████████| 5.2 MB 9.6 MB/s
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.7/dist-packages (from selenium) (2022.9.24)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting urllib3[socks]~=1.26
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 56.3 MB/s
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      |████████████████████████████████| 384 kB 50.8 MB/s
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.0.4-py3-none-any.whl (14 kB)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.5 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (4.1.1)
# Installing collected packages: sniffio, outcome, h11, exceptiongroup, async-generator, wsproto, urllib3, trio, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.12 which is incompatible.
# Successfully installed async-generator-1.10 exceptiongroup-1.0.4 h11-0.14.0 outcome-1.2.0 selenium-4.6.0 sniffio-1.3.0 trio-0.22.0 trio-websocket-0.9.2 urllib3-1.26.12 wsproto-1.2.0

# %%
from selenium import webdriver #importing selenium package
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import time

driver = webdriver.Chrome('chromedriver',options=options)
link = 'https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv'
title_array = []
review_array = []
driver.get(link)
for num in range(4):
  driver.find_element(By.CLASS_NAME,"ipl-load-more__button").click()
  time.sleep(5)
  listOfTitle = driver.find_elements(By.CLASS_NAME, "title")
  listOfReviews = driver.find_elements(By.CLASS_NAME, "text")
for ele, sub_ele in zip(listOfTitle, listOfReviews):
      title_array.append((ele.text).replace('\n',''))
      review_array.append(sub_ele.text)
df = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# Length of data frame is 125
#                                                  Title  \
# 0        I would not call it a masterpiece as some did
# 1        Not a spoon feeding of CGI fueled faux drama.
# 2                           Is it great? I don't know.
# 3                             Perfect in every aspect.
# 4    A psychological study, rather than a superhero...
# ..                                                 ...
# 120                                       Oscar winner
# 121                            There Are No Capes Here
# 122  If you're an outcast, you'll understand this m...
# 123                  A Cynical Movie For Cynical Times
# 124  Incredible movie! And one of the best 2019 mov...
#
#                                                 Review
# 0
# 1    The movie affects you in a way that makes it p...
# 2    When I heard everyone saying that this is the ...
# 3    Truly a masterpiece, The Best Hollywood film o...
# 4    I have seen Joker yesterday at Venice an early...
# ..                                                 ...
# 120
# 121  Joaquin Phoenix transforms into the titular ch...
# 122  And I'm not saying you need to be a freak. Man...
# 123  Who is the crazier one? The one who is able to...
# 124  This is the movie where the audience will like...
#
# [125 rows x 2 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package extended_omw to /root/nltk_data...
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        | Downloading package omw-1.4 to /root/nltk_data...
#        |   Package omw-1.4 is already up-to-date!
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pe08 to /root/nltk_data...
#        |   Unzipping corpora/pe08.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Package stopwords is already up-to-date!
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Package wordnet is already up-to-date!
#        | Downloading package wordnet2021 to /root/nltk_data...
#        | Downloading package wordnet31 to /root/nltk_data...
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Package words is already up-to-date!
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        |
#      Done downloading collection all
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
df['Lower Case'] = df['Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['Removal of Punctuation'] = df['Lower Case'].str.replace('[^\w\s]','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
import re
df['Removal of Special Characters'] = df['Removal of Punctuation'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = stopwords.words('english')
df['Stopwords Removal'] = df['Removal of Punctuation'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from textblob import TextBlob
df['Spelling Correction'] = df['Stopwords Removal'].apply(lambda x: str(TextBlob(x).correct()))
import nltk
nltk.download('punkt')
df['Tokenization'] = df['Spelling Correction'].apply(lambda x: TextBlob(x).words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['After Stemming'] = df['Tokenization'].apply(lambda x: " ".join([st.stem(word) for word in x]))
from textblob import Word
import nltk
nltk.download('wordnet')

df['After Lemmatization'] = df['After Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df.to_csv('/content/sample_data/reviwes.csv',index=False)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import itertools
import collections
from nltk import ngrams
from nltk.tokenize import word_tokenize

words_sentence = []
for sentence in df['After Lemmatization']:
  words_sentence.append(word_tokenize(sentence))
aftercleaning = [x for x in words_sentence if x != []]
iterations = list(itertools.chain.from_iterable(aftercleaning))

# %%
tri_grams = nltk.trigrams(iterations)
frequency_dist = nltk.FreqDist(tri_grams)
frequency_dist
# Out:
# FreqDist({('taxi', 'driver', 'king'): 6, ('driver', 'king', 'comedi'): 6, ('director', 'told', 'phillip'): 6, ('robert', 'de', 'no'): 6, ('dark', 'knight', 'trilog'): 5, ('perform', 'joaquin', 'phoenix'): 5, ('one', 'best', 'perform'): 4, ('chain', 'modern', 'time'): 3, ('10', 'star', 'review'): 3, ('joke', 'first', 'time'): 3, ...})

# %%
from collections import Counter
bi_grams = nltk.bigrams(iterations)
frequency_dist = nltk.FreqDist(bi_grams)
bi_grams_dict = dict(frequency_dist)
for word in bi_grams_dict:
  print( str(word) + ':' + str(bi_grams_dict[word] / iterations.count(word[0])))
# Out:
# Streaming output truncated to the last 5000 lines.
# ('nod', 'greater'):0.2
# ('greater', 'batman'):0.3333333333333333
# ('univers', 'yet'):0.125
# ('yet', 'movi'):0.14285714285714285
# ('movi', 'self'):0.005025125628140704
# ('self', 'contain'):0.3333333333333333
# ('contain', 'charact'):1.0
# ('piec', 'mark'):0.125
# ('mark', 'great'):0.6666666666666666
# ('movi', 'act'):0.005025125628140704
# ('act', 'great'):0.023255813953488372
# ('great', 'plot'):0.024390243902439025
# ('plot', 'similar'):0.0625
# ('driver', 'brilliant'):0.043478260869565216
# ('brilliant', 'qualiti'):0.25
# ('show', 'dont'):0.05555555555555555
# ('need', 'chi'):0.05
# ('chi', 'super'):0.25
# ('super', 'power'):0.16666666666666666
# ('power', 'great'):0.25
# ('great', 'villain'):0.024390243902439025
# ('villain', 'superhero'):0.05263157894736842
# ('joke', 'everyon'):0.013071895424836602
# ('everyon', 'get'):0.06666666666666667
# ('movi', 'rise'):0.005025125628140704
# ('rise', 'joke'):0.3333333333333333
# ('joke', '1010'):0.006535947712418301
# ('1010', 'one'):0.14285714285714285
# ('one', 'prescreen'):0.015384615384615385
# ('prescreen', 'citi'):1.0
# ('citi', 'taken'):0.07692307692307693
# ('taken', 'review'):0.25
# ('review', 'titl'):0.043478260869565216
# ('titl', 'give'):0.25
# ('give', 'torn'):0.037037037037037035
# ('torn', 'ye'):1.0
# ('ye', 'joaquin'):0.16666666666666666
# ('phoenix', 'alway'):0.010869565217391304
# ('alway', 'verit'):0.16666666666666666
# ('verit', 'action'):1.0
# ('action', 'talent'):0.058823529411764705
# ('talent', 'wast'):0.16666666666666666
# ('wast', 'role'):0.16666666666666666
# ('role', 'ye'):0.07142857142857142
# ('ye', 'phoenix'):0.16666666666666666
# ('portray', 'charact'):0.1111111111111111
# ('charact', 'riot'):0.014492753623188406
# ('riot', 'ye'):0.25
# ('ye', 'stori'):0.16666666666666666
# ('stori', 'grip'):0.02631578947368421
# ('grip', 'also'):0.3333333333333333
# ('also', 'necessari'):0.038461538461538464
# ('necessari', 'especi'):1.0
# ('especi', 'today'):0.16666666666666666
# ('today', 'seem'):0.3333333333333333
# ('seem', 'mental'):0.05555555555555555
# ('ill', 'run'):0.043478260869565216
# ('run', 'rampart'):0.2
# ('rampart', 'ye'):0.5
# ('ye', 'tone'):0.16666666666666666
# ('tone', 'magnific'):0.2
# ('magnific', 'set'):1.0
# ('set', 'within'):0.06666666666666667
# ('within', 'cinemat'):0.16666666666666666
# ('cinemat', 'art'):0.14285714285714285
# ('art', 'direct'):0.1
# ('direct', 'problem'):0.06666666666666667
# ('problem', 'way'):0.1
# ('way', 'tie'):0.030303030303030304
# ('univers', 'particularli'):0.125
# ('particularli', 'common'):0.25
# ('common', 'differenti'):0.25
# ('differenti', 'joke'):1.0
# ('joke', 'past'):0.006535947712418301
# ('past', 'still'):0.16666666666666666
# ('still', 'problem'):0.1
# ('problem', 'make'):0.1
# ('make', 'two'):0.017857142857142856
# ('two', 'world'):0.5
# ('world', 'merg'):0.06666666666666667
# ('merg', 'film'):1.0
# ('film', 'surpass'):0.006172839506172839
# ('surpass', 'film'):1.0
# ('film', 'portray'):0.006172839506172839
# ('portray', 'slow'):0.05555555555555555
# ('slow', 'descent'):0.2
# ('mad', 'caus'):0.07692307692307693
# ('caus', 'biolog'):0.125
# ('biolog', 'psycholog'):0.5
# ('psycholog', 'social'):0.1
# ('social', 'familiar'):0.125
# ('familiar', 'factor'):0.25
# ('factor', 'also'):1.0
# ('also', 'highlight'):0.038461538461538464
# ('highlight', 'decay'):0.5
# ('decay', 'n'):1.0
# ('n', 'broken'):0.2
# ('broken', 'system'):0.16666666666666666
# ('system', 'n'):0.09090909090909091
# ('n', 'societi'):0.2
# ('societi', 'auster'):0.03333333333333333
# ('auster', 'film'):1.0
# ('film', 'dark'):0.012345679012345678
# ('dark', 'amaz'):0.024390243902439025
# ('amaz', 'cinematographi'):0.06666666666666667
# ('cinematographi', 'n'):0.037037037037037035
# ('n', 'year'):0.2
# ('year', 'best'):0.041666666666666664
# ('perform', 'phoenix'):0.017241379310344827
# ('phoenix', 'surrealist'):0.010869565217391304
# ('surrealist', 'feel'):1.0
# ('feel', 'n'):0.018867924528301886
# ('n', 'fact'):0.2
# ('fact', 'solid'):0.07142857142857142
# ('solid', 'non'):1.0
# ('non', 'horror'):0.5
# ('horror', 'film'):0.375
# ('film', 'terrifi'):0.006172839506172839
# ('terrifi', 'n'):0.3333333333333333
# ('n', 'poignant'):0.2
# ('poignant', 'went'):1.0
# ('went', 'film'):0.25
# ('film', 'expect'):0.012345679012345678
# ('expect', 'allie'):0.05555555555555555
# ('allie', 'classic'):1.0
# ('classic', 'base'):0.16666666666666666
# ('base', 'review'):0.16666666666666666
# ('review', 'read'):0.043478260869565216
# ('read', 'end'):0.5
# ('end', 'watch'):0.09090909090909091
# ('watch', 'decent'):0.023255813953488372
# ('decent', 'film'):0.5
# ('film', 'overal'):0.012345679012345678
# ('overal', 'phoenix'):0.09090909090909091
# ('phoenix', 'outstand'):0.010869565217391304
# ('outstand', 'definit'):0.3333333333333333
# ('definit', 'part'):0.08333333333333333
# ('part', 'feel'):0.1
# ('like', 'you'):0.017241379310344827
# ('you', 'seen'):0.2222222222222222
# ('seen', 'trailer'):0.04
# ('trailer', 'you'):0.16666666666666666
# ('movi', 'best'):0.005025125628140704
# ('best', 'way'):0.025
# ('way', 'describ'):0.030303030303030304
# ('describ', 'film'):0.3333333333333333
# ('film', 'feel'):0.012345679012345678
# ('like', '2'):0.017241379310344827
# ('2', 'hour'):0.3333333333333333
# ('hour', 'version'):0.2
# ('version', 'trailer'):0.3333333333333333
# ('trailer', '2'):0.16666666666666666
# ('hour', 'rel'):0.2
# ('rel', 'common'):0.5
# ('common', 'aunti'):0.25
# ('aunti', 'felt'):1.0
# ('felt', 'lot'):0.09090909090909091
# ('lot', 'longerwhich'):0.07142857142857142
# ('longerwhich', 'isn'):1.0
# ('isn', 'good'):0.15384615384615385
# ('good', 'id'):0.0196078431372549
# ('say', 'much'):0.024390243902439025
# ('much', 'rental'):0.03333333333333333
# ('rental', 'theater'):1.0
# ('theater', 'movi'):0.5
# ('movi', 'kind'):0.010050251256281407
# ('kind', 'just'):0.06666666666666667
# ('just', 'take'):1.0
# ('take', 'next'):0.037037037037037035
# ('next', 'ingredi'):0.2
# ('ingredi', 'king'):1.0
# ('comedi', 'requir'):0.07692307692307693
# ('requir', 'dream'):0.3333333333333333
# ('dream', 'dark'):0.2
# ('knight', 'taxi'):0.06666666666666667
# ('driver', 'mix'):0.043478260869565216
# ('mix', 'ladi'):0.2
# ('ladi', 'gentleman'):1.0
# ('gentleman', 'joke'):1.0
# ('everyon', 'riot'):0.06666666666666667
# ('riot', 'violent'):0.25
# ('violent', 'actor'):0.07692307692307693
# ('actor', 'skill'):0.05555555555555555
# ('skill', 'isn'):0.3333333333333333
# ('isn', 'great'):0.07692307692307693
# ('great', 'laugh'):0.024390243902439025
# ('laugh', 'anyon'):0.1111111111111111
# ('anyon', 'joke'):0.16666666666666666
# ('joke', 'nomin'):0.006535947712418301
# ('nomin', 'academi'):0.125
# ('academi', 'award'):1.0
# ('award', 'joke'):0.14285714285714285
# ('joke', 'creativ'):0.006535947712418301
# ('creativ', 'actor'):0.25
# ('actor', 'joaquin'):0.1111111111111111
# ('joaquin', 'creativ'):0.0136986301369863
# ('creativ', 'embodi'):0.25
# ('embodi', 'role'):0.3333333333333333
# ('role', 'joke'):0.14285714285714285
# ('film', 'deserv'):0.006172839506172839
# ('deserv', '10'):0.0625
# ('10', 'batman'):0.16666666666666666
# ('batman', 'fan'):0.04
# ('fan', 'particularli'):0.16666666666666666
# ('particularli', 'fond'):0.25
# ('fond', 'joaquin'):1.0
# ('phoenix', 'movi'):0.021739130434782608
# ('movi', 'truli'):0.005025125628140704
# ('truli', 'except'):0.08333333333333333
# ('except', 'start'):0.25
# ('start', 'slow'):0.14285714285714285
# ('slow', 'built'):0.1
# ('built', 'viscer'):1.0
# ('viscer', 'satisfi'):0.5
# ('satisfi', 'crescent'):0.25
# ('crescent', 'never'):1.0
# ('would', 'foot'):0.02857142857142857
# ('foot', 'joke'):0.3333333333333333
# ('joke', 'found'):0.006535947712418301
# ('found', 'throughout'):0.25
# ('joke', 'pain'):0.006535947712418301
# ('pain', 'palpabl'):0.25
# ('palpabl', 'fill'):1.0
# ('fill', 'oscar'):0.3333333333333333
# ('oscar', 'pool'):0.047619047619047616
# ('pool', 'card'):0.5
# ('card', 'right'):1.0
# ('right', 'is'):0.07142857142857142
# ('is', 'movi'):0.3333333333333333
# ('dark', 'violent'):0.024390243902439025
# ('violent', 'decidedli'):0.07692307692307693
# ('decidedli', 'super'):1.0
# ('super', 'hero'):0.3333333333333333
# ('hero', 'movi'):0.4444444444444444
# ('movi', 'leav'):0.005025125628140704
# ('leav', 'kiss'):0.125
# ('kiss', 'home'):0.3333333333333333
# ('home', 'good'):0.3333333333333333
# ('movi', 'hollywood'):0.005025125628140704
# ('hollywood', 'final'):0.25
# ('final', 'good'):0.2
# ('act', 'predict'):0.023255813953488372
# ('predict', 'good'):0.3333333333333333
# ('good', 'twist'):0.0196078431372549
# ('twist', 'build'):0.1
# ('stori', 'howev'):0.02631578947368421
# ('howev', 'some'):0.125
# ('some', 'charact'):1.0
# ('charact', 'flat'):0.014492753623188406
# ('flat', 'crowd'):0.5
# ('crowd', 'scene'):0.5
# ('scene', 'silli'):0.047619047619047616
# ('silli', 'still'):0.5
# ('still', 'font'):0.1
# ('font', 'good'):1.0
# ('good', 'crowd'):0.0196078431372549
# ('crowd', 'director'):0.5
# ('director', 'background'):0.058823529411764705
# ('background', 'artist'):0.2
# ('artist', 'hang'):0.2
# ('hang', 'around'):1.0
# ('around', 'aimlessli'):0.1
# ('aimlessli', 'charact'):0.5
# ('charact', 'without'):0.014492753623188406
# ('without', 'sen'):0.05555555555555555
# ('sen', 'music'):0.14285714285714285
# ('music', 'loud'):0.1
# ('loud', 'usual'):0.5
# ('usual', 'sound'):0.125
# ('sound', 'loud'):0.09090909090909091
# ('loud', 'special'):0.5
# ('effect', 'much'):0.1
# ('much', 'nice'):0.03333333333333333
# ('nice', 'music'):0.25
# ('music', 'choic'):0.1
# ('choic', 'luckili'):0.2
# ('luckili', 'mani'):1.0
# ('mani', 'much'):0.037037037037037035
# ('much', 'special'):0.03333333333333333
# ('effect', 'sound'):0.1
# ('sound', 'use'):0.09090909090909091
# ('use', 'great'):0.08333333333333333
# ('great', 'work'):0.024390243902439025
# ('director', 'nice'):0.058823529411764705
# ('nice', 'cut'):0.25
# ('cut', 'good'):0.3333333333333333
# ('good', 'screenplay'):0.0196078431372549
# ('screenplay', 'good'):0.16666666666666666
# ('good', 'visual'):0.0196078431372549
# ('visual', 'art'):0.25
# ('art', 'wish'):0.1
# ('wish', 'see'):0.5
# ('see', 'next'):0.024390243902439025
# ('next', 'part'):0.2
# ('part', 'style'):0.1
# ('style', 'wish'):0.16666666666666666
# ('see', 'batman'):0.04878048780487805
# ('batman', 'charact'):0.04
# ('charact', 'watchabl'):0.014492753623188406
# ('watchabl', 'style'):0.5
# ('style', 'would'):0.16666666666666666
# ('would', 'even'):0.02857142857142857
# ('even', 'put'):0.02857142857142857
# ('put', 'le'):0.07142857142857142
# ('le', 'action'):0.25
# ('action', 'wish'):0.058823529411764705
# ('batman', 'twist'):0.04
# ('twist', 'charact'):0.1
# ('charact', 'real'):0.014492753623188406
# ('real', 'deep'):0.05555555555555555
# ('deep', 'drama'):0.16666666666666666
# ('drama', 'hop'):0.09090909090909091
# ('hop', 'see'):1.0
# ('see', 'good'):0.024390243902439025
# ('good', 'move'):0.0196078431372549
# ('like', 'quit'):0.017241379310344827
# ('quit', 'reli'):0.06666666666666667
# ('reli', 'critic'):0.5
# ('critic', 'review'):0.1111111111111111
# ('review', 'year'):0.043478260869565216
# ('year', 'ago'):0.041666666666666664
# ('ago', 'notic'):0.5
# ('notic', 'movi'):0.16666666666666666
# ('movi', 'critic'):0.005025125628140704
# ('critic', 'rate'):0.1111111111111111
# ('rate', 'low'):0.14285714285714285
# ('low', 'viewer'):0.25
# ('viewer', 'rate'):0.1111111111111111
# ('rate', 'high'):0.14285714285714285
# ('high', 'said'):0.16666666666666666
# ('said', 'point'):0.25
# ('point', 'critic'):0.05555555555555555
# ('critic', 'movi'):0.1111111111111111
# ('movi', 'oh'):0.005025125628140704
# ('oh', 'wrong'):0.3333333333333333
# ('wrong', 'went'):0.2
# ('went', 'saw'):0.25
# ('saw', 'tone'):0.5
# ('tone', 'mon'):0.2
# ('mon', 'went'):0.16666666666666666
# ('went', 'skeptic'):0.25
# ('skeptic', 'w'):0.5
# ('w', 'low'):1.0
# ('low', 'expect'):0.25
# ('expect', 'knew'):0.05555555555555555
# ('knew', 'expect'):0.5
# ('typic', 'super'):0.25
# ('got', 'masterpiec'):0.2
# ('masterpiec', 'went'):0.041666666666666664
# ('went', 'expect'):0.25
# ('expect', 'sheer'):0.05555555555555555
# ('sheer', 'boredom'):1.0
# ('boredom', 'instead'):1.0
# ('instead', 'edg'):0.2
# ('edg', 'seat'):0.6666666666666666
# ('seat', 'whole'):0.2
# ('whole', 'time'):0.125
# ('time', 'action'):0.017241379310344827
# ('action', 'edg'):0.058823529411764705
# ('seat', 'fear'):0.2
# ('fear', 'may'):0.25
# ('may', 'say'):0.1
# ('say', 'next'):0.024390243902439025
# ('next', 'edg'):0.2
# ('seat', 'see'):0.2
# ('see', 'charact'):0.024390243902439025
# ('charact', 'evolv'):0.014492753623188406
# ('evolv', 'know'):1.0
# ('know', '1'):0.041666666666666664
# ('1', 'villain'):0.5
# ('villain', 'batman'):0.05263157894736842
# ('batman', 'beyond'):0.04
# ('beyond', 'geniu'):1.0
# ('geniu', 'joaquin'):0.3333333333333333
# ('phoenix', 'true'):0.010869565217391304
# ('true', 'master'):0.14285714285714285
# ('master', 'perfect'):0.25
# ('perfect', 'art'):0.08333333333333333
# ('art', 'consum'):0.1
# ('consum', 'charact'):1.0
# ('charact', 'may'):0.014492753623188406
# ('may', 'place'):0.1
# ('place', 'dont'):0.09090909090909091
# ('dont', 'care'):0.03125
# ('care', 'movi'):0.14285714285714285
# ('movi', 'stori'):0.010050251256281407
# ('direct', 'effect'):0.06666666666666667
# ('effect', 'everyon'):0.1
# ('everyon', 'brought'):0.06666666666666667
# ('brought', 'game'):1.0
# ('game', 'up'):0.3333333333333333
# ('up', 'definit'):1.0
# ('definit', 'deserv'):0.08333333333333333
# ('deserv', 'nod'):0.0625
# ('nod', 'win'):0.2
# ('win', 'role'):0.125
# ('role', 'comparison'):0.07142857142857142
# ('comparison', 'jack'):0.2
# ('jack', 'nicholson'):1.0
# ('nicholson', 'heath'):0.6666666666666666
# ('ledger', 'actor'):0.058823529411764705
# ('actor', 'took'):0.05555555555555555
# ('took', 'charact'):0.3333333333333333
# ('charact', 'differ'):0.014492753623188406
# ('differ', 'level'):0.058823529411764705
# ('level', 'differ'):0.2
# ('differ', 'stori'):0.058823529411764705
# ('stori', 'point'):0.02631578947368421
# ('point', 'differ'):0.05555555555555555
# ('differ', 'point'):0.058823529411764705
# ('point', 'time'):0.05555555555555555
# ('time', 'comparison'):0.017241379310344827
# ('comparison', 'would'):0.2
# ('would', 'feasibl'):0.02857142857142857
# ('feasibl', 'fair'):1.0
# ('fair', 'actor'):0.5
# ('actor', 'embrac'):0.05555555555555555
# ('embrac', 'made'):0.5
# ('made', 'come'):0.05555555555555555
# ('come', 'life'):0.05263157894736842
# ('life', 'geniu'):0.043478260869565216
# ('geniu', 'way'):0.3333333333333333
# ('joke', 'liter'):0.006535947712418301
# ('liter', 'achiev'):0.5
# ('achiev', 'cinemat'):0.2
# ('cinemat', 'histori'):0.14285714285714285
# ('histori', 'there'):0.2
# ('there', 'doubt'):0.08333333333333333
# ('doubt', 'peopl'):0.3333333333333333
# ('peopl', 'compar'):0.024390243902439025
# ('compar', 'engag'):0.25
# ('engag', 'move'):0.2
# ('move', 'way'):0.022727272727272728
# ('way', 'complet'):0.030303030303030304
# ('complet', 'differ'):0.14285714285714285
# ('differ', 'engag'):0.058823529411764705
# ('engag', 'best'):0.2
# ('best', 'gene'):0.025
# ('gene', 'talk'):0.1111111111111111
# ('talk', 'joke'):0.08333333333333333
# ('joke', 'say'):0.006535947712418301
# ('say', 'beauti'):0.024390243902439025
# ('beauti', 'present'):0.14285714285714285
# ('present', 'storylin'):0.1
# ('storylin', 'direct'):0.25
# ('screenplay', 'peak'):0.16666666666666666
# ('peak', 'great'):1.0
# ('great', 'heath'):0.024390243902439025
# ('ledger', 'smile'):0.058823529411764705
# ('smile', 'earth'):0.2
# ('earth', 'serious'):1.0
# ('serious', 'unbeliev'):0.25
# ('unbeliev', 'dare'):1.0
# ('dare', 'say'):0.3333333333333333
# ('say', 'better'):0.024390243902439025
# ('better', 'heath'):0.1111111111111111
# ('ledger', 'joaquin'):0.058823529411764705
# ('doesn', 'win'):0.15384615384615385
# ('oscar', 'best'):0.047619047619047616
# ('best', 'actor'):0.05
# ('actor', 'joke'):0.05555555555555555
# ('joke', 'doesn'):0.006535947712418301
# ('win', 'least'):0.125
# ('least', 'best'):0.08333333333333333
# ('best', 'screenplay'):0.025
# ('screenplay', 'one'):0.16666666666666666
# ('one', 'biggest'):0.015384615384615385
# ('biggest', 'oscar'):0.5
# ('oscar', 'snub'):0.047619047619047616
# ('snub', 'time'):1.0
# ('time', 'greet'):0.017241379310344827
# ('greet', 'dark'):0.5
# ('dark', 'first'):0.024390243902439025
# ('first', 'thing'):0.0625
# ('thing', 'know'):0.08695652173913043
# ('know', 'superhero'):0.041666666666666664
# ('movi', 'fact'):0.005025125628140704
# ('fact', 'hero'):0.07142857142857142
# ('movi', 'unless'):0.005025125628140704
# ('unless', 'would'):1.0
# ('like', 'appli'):0.017241379310344827
# ('appli', 'label'):0.5
# ('label', 'singl'):1.0
# ('singl', 'mon'):0.2857142857142857
# ('mon', 'live'):0.16666666666666666
# ('live', 'hall'):0.09090909090909091
# ('hall', 'arthur'):1.0
# ('fleck', 'mr'):0.03225806451612903
# ('mr', 'fleck'):0.5
# ('fleck', 'live'):0.03225806451612903
# ('live', 'home'):0.09090909090909091
# ('home', 'invalid'):0.3333333333333333
# ('invalid', 'mother'):1.0
# ('mother', 'wrung'):0.25
# ('wrung', 'renown'):1.0
# ('renown', 'apart'):1.0
# ('apart', 'work'):0.3333333333333333
# ('work', 'clownforhir'):0.05263157894736842
# ('clownforhir', 'dream'):1.0
# ('dream', 'becom'):0.2
# ('becom', 'stand'):0.08333333333333333
# ('stand', 'comedian'):0.3333333333333333
# ('comedian', 'depend'):0.3333333333333333
# ('depend', 'social'):0.5
# ('servic', 'suppli'):0.25
# ('suppli', '7'):1.0
# ('7', 'medit'):1.0
# ('medit', 'take'):0.3333333333333333
# ('take', 'sinc'):0.037037037037037035
# ('sinc', 'releas'):0.1
# ('releas', 'abraham'):0.25
# ('abraham', 'state'):1.0
# ('state', 'hospit'):0.3333333333333333
# ('hospit', 'bleak'):1.0
# ('bleak', 'exist'):0.25
# ('exist', 'bleak'):0.14285714285714285
# ('bleak', 'time'):0.25
# ('time', 'bleak'):0.017241379310344827
# ('bleak', 'citi'):0.25
# ('citi', 'gothic'):0.07692307692307693
# ('gothic', 'midst'):0.06666666666666667
# ('midst', 'garag'):0.5
# ('garag', 'worker'):0.25
# ('worker', 'strike'):0.5
# ('strike', 'super'):0.5
# ('super', 'rat'):0.16666666666666666
# ('rat', 'happi'):0.3333333333333333
# ('happi', 'polit'):0.25
# ('polit', 'upheav'):0.25
# ('upheav', 'grow'):1.0
# ('grow', 'chasm'):0.3333333333333333
# ('chasm', 'class'):1.0
# ('class', 'get'):0.09090909090909091
# ('get', 'wors'):0.019230769230769232
# ('wors', 'arthur'):0.25
# ('arthur', 'second'):0.017857142857142856
# ('second', 'thing'):0.3333333333333333
# ('know', 'standalon'):0.041666666666666664
# ('standalon', 'joke'):0.25
# ('film', 'one'):0.012345679012345678
# ('one', 'mostli'):0.015384615384615385
# ('mostli', 'unrel'):1.0
# ('unrel', 'connect'):1.0
# ('connect', 'previou'):0.25
# ('previou', 'project'):0.5
# ('project', 'fear'):1.0
# ('fear', 'colour'):0.25
# ('colour', 'clown'):1.0
# ('princ', 'charact'):0.3333333333333333
# ('charact', 'play'):0.014492753623188406
# ('play', 'voic'):0.06666666666666667
# ('voic', 'memor'):0.3333333333333333
# ('memor', 'actor'):0.25
# ('actor', 'caesar'):0.05555555555555555
# ('caesar', 'robert'):1.0
# ('robert', 'jack'):0.14285714285714285
# ('ledger', 'mark'):0.058823529411764705
# ('mark', 'famili'):0.3333333333333333
# ('famili', 'dare'):0.5
# ('dare', 'let'):0.3333333333333333
# ('let', 'even'):0.16666666666666666
# ('even', 'each'):0.02857142857142857
# ('each', 'galifianaki'):0.5
# ('galifianaki', 'director'):1.0
# ('phillip', 'wrote'):0.027777777777777776
# ('wrote', 'script'):0.5
# ('script', 'scott'):0.2
# ('scott', 'silver'):1.0
# ('silver', 'best'):0.5
# ('best', 'known'):0.025
# ('known', 'extrem'):0.2
# ('extrem', 'remedi'):0.3333333333333333
# ('remedi', 'hanov'):1.0
# ('hanov', 'franchis'):0.2
# ('franchis', 'old'):0.25
# ('old', 'school'):0.6666666666666666
# ('school', 'he'):0.3333333333333333
# ('he', 'bit'):0.14285714285714285
# ('bit', 'outsid'):0.125
# ('outsid', 'usual'):0.5
# ('usual', 'wheelhous'):0.125
# ('wheelhous', 'phillip'):1.0
# ('phillip', 'silver'):0.027777777777777776
# ('silver', 'seem'):0.5
# ('seem', 'embrac'):0.05555555555555555
# ('embrac', 'histori'):0.5
# ('histori', 'charact'):0.2
# ('charact', 'also'):0.014492753623188406
# ('also', 'look'):0.038461538461538464
# ('look', 'textur'):0.03571428571428571
# ('textur', 'tone'):1.0
# ('tone', 'filmmak'):0.2
# ('filmmak', 'earlier'):0.3333333333333333
# ('earlier', 'era'):1.0
# ('era', 'gritti'):1.0
# ('gritti', 'outcast'):0.125
# ('outcast', 'feel'):0.3333333333333333
# ('feel', 'scorces'):0.018867924528301886
# ('scorces', 'taxi'):1.0
# ('comedi', 'present'):0.07692307692307693
# ('present', 'numer'):0.1
# ('numer', 'tribut'):0.5
# ('tribut', 'familiar'):0.3333333333333333
# ('familiar', 'joke'):0.25
# ('moment', 'day'):0.1111111111111111
# ('day', 'gone'):0.14285714285714285
# ('gone', 'three'):0.3333333333333333
# ('three', 'time'):0.16666666666666666
# ('time', 'oscar'):0.017241379310344827
# ('oscar', 'nomine'):0.047619047619047616
# ('nomine', 'joaquin'):1.0
# ('phoenix', 'play'):0.03260869565217391
# ('play', 'arthur'):0.06666666666666667
# ('fleck', 'deliv'):0.03225806451612903
# ('deliv', 'arthur'):0.125
# ('arthur', 'slow'):0.017857142857142856
# ('mad', 'shall'):0.07692307692307693
# ('shall', 'say'):1.0
# ('say', 'descent'):0.024390243902439025
# ('descent', 'clear'):0.16666666666666666
# ('clear', 'begin'):0.25
# ('begin', 'arthur'):0.16666666666666666
# ('arthur', 'view'):0.017857142857142856
# ('view', 'ignor'):0.125
# ('ignor', 'societi'):0.16666666666666666
# ('societi', 'want'):0.03333333333333333
# ('want', 'bring'):0.03571428571428571
# ('bring', 'joy'):0.08333333333333333
# ('joy', 'laughter'):1.0
# ('laughter', 'other'):0.2
# ('other', 'notic'):0.1
# ('notic', 'daydream'):0.16666666666666666
# ('daydream', 'vision'):1.0
# ('vision', 'better'):0.5
# ('better', 'world'):0.05555555555555555
# ('world', 'send'):0.06666666666666667
# ('send', 'strong'):0.5
# ('strong', 'messag'):0.3333333333333333
# ('messag', 'phoenix'):0.1111111111111111
# ('phoenix', 'show'):0.010869565217391304
# ('show', 'u'):0.05555555555555555
# ('u', 'full'):0.058823529411764705
# ('full', 'commit'):0.2
# ('commit', 'role'):0.4
# ('role', 'look'):0.07142857142857142
# ('like', 'lost'):0.017241379310344827
# ('lost', '50'):0.3333333333333333
# ('50', 'pound'):1.0
# ('pound', 'leav'):1.0
# ('leav', 'frame'):0.125
# ('frame', 'content'):0.16666666666666666
# ('content', 'move'):0.3333333333333333
# ('move', 'danc'):0.022727272727272728
# ('danc', 'manner'):0.16666666666666666
# ('manner', 'unlik'):0.25
# ('unlik', 'were'):0.5
# ('were', 'seen'):0.25
# ('seen', 'fact'):0.04
# ('fact', 'tissu'):0.07142857142857142
# ('tissu', 'show'):1.0
# ('show', 'frequent'):0.05555555555555555
# ('frequent', 'danc'):0.3333333333333333
# ('danc', 'move'):0.16666666666666666
# ('move', 'magic'):0.022727272727272728
# ('magic', 'pain'):0.3333333333333333
# ('pain', 'laughter'):0.25
# ('laughter', 'inform'):0.2
# ('inform', 'arthur'):1.0
# ('arthur', 'suffer'):0.017857142857142856
# ('suffer', 'pseudobulbar'):0.3333333333333333
# ('pseudobulbar', 'affect'):1.0
# ('affect', 'also'):0.3333333333333333
# ('also', 'known'):0.038461538461538464
# ('known', 'emot'):0.2
# ('emot', 'incontin'):0.07692307692307693
# ('incontin', 'caus'):1.0
# ('caus', 'creep'):0.125
# ('creep', 'laughter'):0.5
# ('laughter', 'pop'):0.2
# ('pop', 'inappropri'):0.3333333333333333
# ('inappropri', 'time'):0.5
# ('time', 'cours'):0.017241379310344827
# ('cours', 'comparison'):0.25
# ('comparison', 'heath'):0.2
# ('ledger', 'oscar'):0.058823529411764705
# ('win', 'turn'):0.125
# ('turn', 'dark'):0.2222222222222222
# ('knight', 'inevit'):0.06666666666666667
# ('inevit', 'role'):0.3333333333333333
# ('role', 'film'):0.07142857142857142
# ('film', 'written'):0.006172839506172839
# ('written', 'quit'):0.5
# ('quit', 'differ'):0.06666666666666667
# ('differ', 'safe'):0.058823529411764705
# ('safe', 'say'):0.5
# ('say', 'actor'):0.024390243902439025
# ('actor', 'allen'):0.05555555555555555
# ('allen', 'action'):1.0
# ('action', 'sequenc'):0.058823529411764705
# ('sequenc', 'special'):0.3333333333333333
# ('special', 'visual'):0.14285714285714285
# ('visual', 'effect'):0.25
# ('effect', 'notic'):0.1
# ('notic', 'absent'):0.16666666666666666
# ('absent', 'violenc'):1.0
# ('violenc', 'sure'):0.058823529411764705
# ('sure', 'shock'):0.05
# ('shock', 'one'):0.3333333333333333
# ('one', 'younger'):0.015384615384615385
# ('younger', 'kiss'):1.0
# ('kiss', 'matter'):0.3333333333333333
# ('matter', 'much'):0.3333333333333333
# ('much', 'enjoy'):0.06666666666666667
# ('enjoy', 'avenu'):0.07692307692307693
# ('avenu', 'wonder'):1.0
# ('wonder', 'woman'):0.14285714285714285
# ('woman', 'do'):0.2
# ('do', 'marvel'):0.0625
# ('marvel', 'film'):1.0
# ('film', 'gritti'):0.012345679012345678
# ('gritti', 'viscer'):0.125
# ('viscer', 'approach'):0.5
# ('approach', 'often'):0.3333333333333333
# ('often', 'tough'):0.2
# ('tough', 'watch'):1.0
# ('watch', 'much'):0.023255813953488372
# ('much', 'charact'):0.03333333333333333
# ('studi', 'mental'):0.1111111111111111
# ('ill', 'costum'):0.043478260869565216
# ('costum', 'drama'):0.2
# ('drama', 'although'):0.09090909090909091
# ('although', 'arthur'):0.5
# ('arthur', 'cloth'):0.017857142857142856
# ('cloth', 'make'):1.0
# ('make', 'front'):0.017857142857142856
# ('front', 'center'):0.3333333333333333
# ('center', 'arthur'):1.0
# ('arthur', 'state'):0.017857142857142856
# ('state', 'noth'):0.3333333333333333
# ('noth', 'bad'):0.14285714285714285
# ('bad', 'thought'):0.05263157894736842
# ('thought', 'believ'):0.058823529411764705
# ('believ', 'sympathet'):0.09090909090909091
# ('sympathet', 'back'):0.3333333333333333
# ('back', 'stori'):0.125
# ('stori', 'explain'):0.02631578947368421
# ('explain', 'great'):0.5
# ('great', 'deal'):0.024390243902439025
# ('deal', 'like'):0.5
# ('like', 'prove'):0.017241379310344827
# ('prove', 'quit'):0.5
# ('quit', 'controversi'):0.06666666666666667
# ('controversi', 'phoenix'):0.25
# ('phoenix', 'domin'):0.010869565217391304
# ('domin', 'film'):1.0
# ('film', 'support'):0.006172839506172839
# ('support', 'work'):0.14285714285714285
# ('work', 'provid'):0.05263157894736842
# ('provid', 'robert'):0.3333333333333333
# ('no', 'murray'):0.1111111111111111
# ('franklin', 'to'):0.2
# ('to', 'talk'):0.3333333333333333
# ('host', 'johnni'):0.25
# ('johnni', 'carson'):1.0
# ('carson', 'mode'):1.0
# ('mode', 'gaze'):1.0
# ('been', 'deadpool'):0.3333333333333333
# ('deadpool', '2'):0.5
# ('2', 'singl'):0.16666666666666666
# ('mon', 'neighbor'):0.16666666666666666
# ('demand', 'franc'):0.25
# ('convoy', 'penni'):0.2
# ('fleck', 'arthur'):0.03225806451612903
# ('arthur', 'mother'):0.017857142857142856
# ('mother', 'brest'):0.25
# ('brest', 'cullen'):1.0
# ('cullen', 'sympathet'):1.0
# ('sympathet', 'thoma'):0.3333333333333333
# ('wayn', 'she'):0.07692307692307693
# ('she', 'brigham'):1.0
# ('brigham', 'bill'):1.0
# ('bill', 'camp'):1.0
# ('camp', 'polic'):1.0
# ('polic', 'detect'):0.5
# ('detect', 'ill'):1.0
# ('ill', 'hesitantli'):0.043478260869565216
# ('hesitantli', 'mention'):1.0
# ('mention', 'date'):0.25
# ('date', 'pereiraolson'):1.0
# ('pereiraolson', 'make'):1.0
# ('make', 'coupl'):0.017857142857142856
# ('coupl', 'brief'):0.25
# ('brief', 'appear'):1.0
# ('appear', 'adolesc'):0.14285714285714285
# ('adolesc', 'bruce'):1.0
# ('bruce', 'wayn'):1.0
# ('wayn', 'fun'):0.07692307692307693
# ('fun', 'get'):0.25
# ('get', 'shot'):0.019230769230769232
# ('shot', 'young'):0.1111111111111111
# ('young', 'man'):0.3333333333333333
# ('man', 'hope'):0.041666666666666664
# ('hope', 'battl'):0.05
# ('battl', 'skill'):0.5
# ('skill', 'use'):0.3333333333333333
# ('use', 'later'):0.08333333333333333
# ('later', 'life'):0.25
# ('life', 'dont'):0.043478260869565216
# ('dont', 'expect'):0.0625
# ('expect', 'real'):0.05555555555555555
# ('real', 'batman'):0.05555555555555555
# ('refer', 'director'):0.16666666666666666
# ('director', 'phillip'):0.058823529411764705
# ('phillip', 'deliv'):0.027777777777777776
# ('deliv', 'film'):0.125
# ('film', 'look'):0.012345679012345678
# ('look', 'feel'):0.03571428571428571
# ('feel', 'sound'):0.018867924528301886
# ('sound', 'much'):0.09090909090909091
# ('much', 'differ'):0.03333333333333333
# ('differ', 'comic'):0.058823529411764705
# ('book', 'move'):0.06666666666666667
# ('move', 'cinematograph'):0.022727272727272728
# ('cinematograph', 'lawrenc'):1.0
# ('lawrenc', 'her'):1.0
# ('her', 'frequent'):0.5
# ('frequent', 'phillip'):0.3333333333333333
# ('phillip', 'collabor'):0.027777777777777776
# ('collabor', '3'):1.0
# ('3', 'hanov'):0.5
# ('move', 'dark'):0.022727272727272728
# ('dark', 'look'):0.024390243902439025
# ('look', 'gritti'):0.03571428571428571
# ('gritti', 'feel'):0.125
# ('feel', 'present'):0.018867924528301886
# ('present', 'everi'):0.1
# ('everi', 'shot'):0.0625
# ('shot', 'holder'):0.1111111111111111
# ('holder', 'guonadottir'):0.3333333333333333
# ('guonadottir', 'year'):1.0
# ('year', 'emma'):0.041666666666666664
# ('emma', 'winner'):1.0
# ('winner', 'chernobyl'):1.0
# ('chernobyl', 'serv'):1.0
# ('serv', 'forebod'):0.5
# ('forebod', 'score'):1.0
# ('score', 'one'):0.038461538461538464
# ('one', 'never'):0.015384615384615385
# ('never', 'overwhelm'):0.045454545454545456
# ('overwhelm', 'one'):0.5
# ('one', 'contrast'):0.015384615384615385
# ('contrast', 'perfectli'):1.0
# ('perfectli', 'tradit'):0.1111111111111111
# ('tradit', 'song'):1.0
# ('song', 'util'):0.3333333333333333
# ('util', 'throughout'):0.3333333333333333
# ('throughout', 'stephen'):0.1
# ('stephen', 'sondheim'):1.0
# ('sondheim', 'send'):1.0
# ('send', 'clown'):0.5
# ('clown', 'jimmi'):0.06666666666666667
# ('jimmi', 'urat'):1.0
# ('urat', 'sing'):1.0
# ('sing', 'smile'):1.0
# ('smile', 'dream'):0.2
# ('dream', 'white'):0.2
# ('white', 'room'):0.5
# ('room', 'that'):1.0
# ('that', 'life'):0.0625
# ('life', 'frank'):0.043478260869565216
# ('frank', 'intra'):1.0
# ('intra', 'mari'):1.0
# ('mari', 'glitter'):1.0
# ('glitter', 'familiar'):0.3333333333333333
# ('familiar', 'rock'):0.25
# ('rock', 'roll'):1.0
# ('roll', 'part'):0.3333333333333333
# ('part', '1'):0.1
# ('1', '2'):0.5
# ('2', 'smile'):0.16666666666666666
# ('smile', 'song'):0.2
# ('song', 'especi'):0.3333333333333333
# ('especi', 'relev'):0.16666666666666666
# ('relev', 'origin'):0.3333333333333333
# ('origin', 'trace'):0.06666666666666667
# ('trace', 'charli'):0.5
# ('charli', 'chain'):0.5
# ('time', 'silent'):0.017241379310344827
# ('silent', 'movi'):1.0
# ('movi', 'classic'):0.005025125628140704
# ('classic', 'featur'):0.16666666666666666
# ('featur', 'film'):0.6666666666666666
# ('film', 'phillip'):0.012345679012345678
# ('phillip', 'even'):0.027777777777777776
# ('even', 'use'):0.02857142857142857
# ('use', 'saul'):0.08333333333333333
# ('saul', 'bass'):1.0
# ('bass', 'design'):1.0
# ('design', 'warn'):0.14285714285714285
# ('warn', 'brow'):1.0
# ('brow', 'log'):1.0
# ('log', 'open'):1.0
# ('open', 'credit'):0.25
# ('credit', 'make'):0.3333333333333333
# ('make', 'sure'):0.017857142857142856
# ('sure', 'understand'):0.05
# ('understand', 'time'):0.18181818181818182
# ('time', 'period'):0.017241379310344827
# ('period', 'cell'):0.5
# ('cell', 'phone'):1.0
# ('phone', 'etc'):1.0
# ('etc', 'film'):1.0
# ('film', 'trace'):0.006172839506172839
# ('trace', 'arthur'):0.5
# ('arthur', 'slide'):0.017857142857142856
# ('slide', 'crime'):0.3333333333333333
# ('crime', 'transit'):0.14285714285714285
# ('transit', 'want'):0.25
# ('want', 'seek'):0.03571428571428571
# ('seek', 'one'):1.0
# ('one', 'believ'):0.015384615384615385
# ('believ', 'forc'):0.09090909090909091
# ('forc', 'upon'):0.16666666666666666
# ('upon', 'rise'):0.25
# ('rise', 'savior'):0.3333333333333333
# ('savior', 'work'):1.0
# ('work', 'class'):0.05263157894736842
# ('class', 'secondari'):0.09090909090909091
# ('secondari', 'journey'):1.0
# ('journey', 'chao'):0.3333333333333333
# ('chao', 'handl'):0.5
# ('handl', 'perimet'):0.5
# ('perimet', 'film'):1.0
# ('film', 'prevent'):0.006172839506172839
# ('prevent', 'becom'):1.0
# ('becom', 'super'):0.16666666666666666
# ('super', 'villain'):0.3333333333333333
# ('villain', 'movi'):0.10526315789473684
# ('keep', 'mind'):0.2222222222222222
# ('mind', 'joke'):0.1
# ('joke', 'play'):0.006535947712418301
# ('play', 'venic'):0.06666666666666667
# ('venic', 'tellurid'):0.3333333333333333
# ('tellurid', 'toronto'):1.0
# ('toronto', 'three'):1.0
# ('three', 'prestigi'):0.16666666666666666
# ('prestigi', 'festiv'):1.0
# ('festiv', 'anoth'):0.5
# ('anoth', 'thing'):0.1111111111111111
# ('thing', 'set'):0.043478260869565216
# ('set', 'apart'):0.06666666666666667
# ('apart', 'other'):0.3333333333333333
# ('other', 'gene'):0.1
# ('gene', 'despit'):0.1111111111111111
# ('despit', '1981'):0.08333333333333333
# ('1981', 'time'):0.5
# ('time', 'stamp'):0.017241379310344827
# ('stamp', 'consist'):1.0
# ('consist', 'antirich'):1.0
# ('antirich', 'messag'):1.0
# ('messag', 'class'):0.1111111111111111
# ('class', 'dispar'):0.09090909090909091
# ('dispar', 'preval'):1.0
# ('preval', 'throughout'):0.3333333333333333
# ('throughout', 'appear'):0.1
# ('appear', 'phillip'):0.14285714285714285
# ('phillip', 'way'):0.027777777777777776
# ('way', 'includ'):0.030303030303030304
# ('includ', 'contemporari'):0.3333333333333333
# ('contemporari', 'theme'):0.3333333333333333
# ('theme', 'decadesold'):0.14285714285714285
# ('decadesold', 'set'):1.0
# ('set', 'cautionari'):0.06666666666666667
# ('cautionari', 'tale'):1.0
# ('tale', 'clown'):0.25
# ('clown', 'left'):0.06666666666666667
# ('behind', 'joaquin'):0.3333333333333333
# ('phoenix', 'produc'):0.010869565217391304
# ('produc', 'one'):0.2
# ('one', 'memor'):0.015384615384615385
# ('memor', 'perform'):0.25
# ('perform', 'ever'):0.034482758620689655
# ('ever', 'captur'):0.043478260869565216
# ('captur', 'featur'):0.125
# ('film', 'earn'):0.006172839506172839
# ('earn', 'hardwar'):0.5
# ('hardwar', 'accolad'):1.0
# ('accolad', 'receiv'):0.5
# ('receiv', 'stun'):1.0
# ('stun', 'disturb'):0.2
# ('disturb', 'portug'):0.05263157894736842
# ('portug', 'joke'):1.0
# ('joaquin', 'put'):0.0136986301369863
# ('put', 'virtuou'):0.07142857142857142
# ('virtuou', 'spotlight'):1.0
# ('spotlight', 'perform'):0.5
# ('perform', 'elev'):0.017241379310344827
# ('elev', 'movi'):1.0
# ('movi', 'legendari'):0.005025125628140704
# ('legendari', 'statu'):0.16666666666666666
# ('statu', 'credit'):0.3333333333333333
# ('credit', 'director'):0.3333333333333333
# ('told', 'philip'):0.07142857142857142
# ('philip', 'build'):0.5
# ('build', 'tension'):0.16666666666666666
# ('tension', 'throughout'):1.0
# ('throughout', 'film'):0.3
# ('film', 'captur'):0.006172839506172839
# ('captur', 'glanc'):0.125
# ('glanc', 'joke'):0.5
# ('joke', 'tortur'):0.006535947712418301
# ('tortur', 'darksid'):0.5
# ('darksid', 'slide'):1.0
# ('slide', 'derang'):0.3333333333333333
# ('derang', 'violent'):0.3333333333333333
# ('violent', 'insan'):0.07692307692307693
# ('insan', 'keep'):0.125
# ('keep', 'film'):0.1111111111111111
# ('film', 'pace'):0.006172839506172839
# ('pace', 'flow'):0.16666666666666666
# ('flow', 'track'):0.25
# ('track', 'without'):1.0
# ('without', 'unnecessari'):0.05555555555555555
# ('unnecessari', 'fill'):0.2
# ('fill', 'util'):0.3333333333333333
# ('util', 'appli'):0.3333333333333333
# ('appli', 'variou'):0.5
# ('variou', 'camera'):0.5
# ('camera', 'lens'):0.5
# ('lens', 'shot'):1.0
# ('shot', 'angl'):0.1111111111111111
# ('angl', 'light'):0.5
# ('light', 'colorshu'):0.25
# ('colorshu', 'apertur'):1.0
# ('apertur', 'set'):1.0
# ('set', 'eg'):0.06666666666666667
# ('eg', 'bone'):1.0
# ('bone', 'scene'):0.2
# ('scene', 'frame'):0.047619047619047616
# ('frame', 'allow'):0.16666666666666666
# ('allow', 'joaquin'):0.16666666666666666
# ('joaquin', 'tap'):0.0136986301369863
# ('tap', 'dark'):1.0
# ('dark', 'corner'):0.024390243902439025
# ('corner', 'util'):1.0
# ('util', 'uniqu'):0.3333333333333333
# ('uniqu', 'act'):0.3333333333333333
# ('act', 'instinct'):0.023255813953488372
# ('instinct', 'develop'):1.0
# ('develop', 'charact'):0.2
# ('charact', 'phoenix'):0.014492753623188406
# ('phoenix', 'act'):0.03260869565217391
# ('perform', 'leav'):0.017241379310344827
# ('leav', 'noth'):0.125
# ('noth', 'tabl'):0.14285714285714285
# ('tabl', 'keep'):1.0
# ('keep', 'score'):0.1111111111111111
# ('score', 'phoenix'):0.038461538461538464
# ('phoenix', 'alli'):0.010869565217391304
# ('alli', 'perfect'):1.0
# ('perfect', '10'):0.08333333333333333
# ('10', 'produc'):0.16666666666666666
# ('produc', 'truli'):0.2
# ('truli', 'legendari'):0.08333333333333333
# ('legendari', 'perform'):0.5
# ('perform', 'transform'):0.017241379310344827
# ('transform', 'film'):0.2
# ('film', 'god'):0.006172839506172839
# ('god', 'know'):0.25
# ('know', 'would'):0.041666666666666664
# ('would', 'anoth'):0.02857142857142857
# ('anoth', 'actor'):0.1111111111111111
# ('actor', '910'):0.05555555555555555
# ('910', 'perform'):1.0
# ('perform', 'film'):0.06896551724137931
# ('one', 'easili'):0.015384615384615385
# ('easili', 'forget'):0.2
# ('forget', 'realli'):0.3333333333333333
# ('realli', 'slow'):0.027777777777777776
# ('pace', 'bore'):0.16666666666666666
# ('bore', 'overhyp'):0.09090909090909091
# ('overhyp', 'opinion'):0.16666666666666666
# ('opinion', 'incred'):0.25
# ('incred', 'ride'):0.06666666666666667
# ('ride', 'almost'):0.25
# ('almost', 'motionless'):0.1
# ('motionless', 'throughout'):1.0
# ('throughout', 'watch'):0.1
# ('watch', 'awe'):0.023255813953488372
# ('awe', 'perform'):1.0
# ('lifetim', 'transit'):0.3333333333333333
# ('transit', 'troubl'):0.25
# ('troubl', 'man'):0.25
# ('man', 'monster'):0.041666666666666664
# ('monster', 'found'):0.25
# ('found', 'score'):0.25
# ('score', 'directli'):0.038461538461538464
# ('directli', 'drove'):0.5
# ('drove', 'goosebump'):1.0
# ('goosebump', 'cinematographi'):1.0
# ('cinematographi', 'made'):0.037037037037037035
# ('like', 'fli'):0.017241379310344827
# ('fli', 'gothic'):1.0
# ('gothic', 'look'):0.13333333333333333
# ('look', 'arthur'):0.03571428571428571
# ('arthur', 'wast'):0.017857142857142856
# ('wast', 'de'):0.16666666666666666
# ('no', 'gave'):0.1111111111111111
# ('gave', 'nod'):0.25
# ('nod', 'merri'):0.2
# ('merri', 'lewi'):1.0
# ('lewi', 'ignor'):0.5
# ('ignor', 'do'):0.16666666666666666
# ('do', 'ignor'):0.0625
# ('ignor', 'batman'):0.16666666666666666
# ('batman', 'work'):0.04
# ('work', 'art'):0.05263157894736842
# ('art', 'right'):0.1
# ('right', 'whether'):0.07142857142857142
# ('whether', 'end'):0.5
# ('end', 'love'):0.09090909090909091
# ('love', 'hate'):0.10526315789473684
# ('hate', 'joke'):0.125
# ('joke', 'told'):0.006535947712418301
# ('phillip', 'gritti'):0.027777777777777776
# ('gritti', 'score'):0.125
# ('score', 'like'):0.038461538461538464
# ('like', 'take'):0.017241379310344827
# ('take', 'legendari'):0.037037037037037035
# ('legendari', 'do'):0.16666666666666666
# ('comic', 'villain'):0.04
# ('villain', 'there'):0.05263157894736842
# ('there', 'deni'):0.08333333333333333
# ('deni', 'cinemat'):1.0
# ('cinemat', 'comic'):0.14285714285714285
# ('book', 'adapt'):0.06666666666666667
# ('adapt', 'landscap'):0.25
# ('landscap', 'chang'):0.5
# ('chang', 'forev'):0.1111111111111111
# ('forev', 'woman'):0.5
# ('woman', 'chang'):0.2
# ('chang', 'expect'):0.1111111111111111
# ('expect', 'comic'):0.05555555555555555
# ('book', 'film'):0.13333333333333333
# ('joke', 'examin'):0.006535947712418301
# ('examin', 'birth'):1.0
# ('birth', 'nefari'):0.5
# ('nefari', 'villain'):1.0
# ('villain', 'hellbent'):0.05263157894736842
# ('hellbent', 'chao'):1.0
# ('chao', 'anarchi'):0.5
# ('anarchi', 'unlik'):1.0
# ('unlik', 'anyth'):0.5
# ('anyth', 'were'):0.09090909090909091
# ('were', 'ever'):0.25
# ('seen', 'strip'):0.04
# ('strip', 'well'):0.5
# ('known', 'charact'):0.2
# ('charact', 'back'):0.014492753623188406
# ('back', 'bare'):0.125
# ('bare', 'basi'):0.2
# ('basi', 'introduc'):1.0
# ('introduc', 'sad'):1.0
# ('sad', 'life'):0.14285714285714285
# ('life', 'misunderstood'):0.043478260869565216
# ('misunderstood', 'unmov'):1.0
# ('unmov', 'arthur'):1.0
# ('fleck', 'share'):0.03225806451612903
# ('share', 'common'):1.0
# ('common', 'drama'):0.25
# ('drama', 'taxi'):0.09090909090909091
# ('driver', 'servic'):0.043478260869565216
# ('servic', 'rather'):0.25
# ('rather', 'comic'):0.14285714285714285
# ('book', 'cousin'):0.06666666666666667
# ('cousin', 'phillip'):1.0
# ('phillip', 'mindbogglingli'):0.027777777777777776
# ('mindbogglingli', 'good'):1.0
# ('good', 'lead'):0.0196078431372549
# ('lead', 'man'):0.2222222222222222
# ('man', 'joaquin'):0.041666666666666664
# ('phoenix', 'take'):0.010869565217391304
# ('take', 'u'):0.037037037037037035
# ('u', 'mind'):0.058823529411764705
# ('mind', 'broken'):0.1
# ('man', 'tri'):0.125
# ('tri', 'fit'):0.08333333333333333
# ('fit', 'world'):0.14285714285714285
# ('world', 'doesn'):0.06666666666666667
# ('doesn', 'want'):0.07692307692307693
# ('want', 'open'):0.03571428571428571
# ('open', 'arm'):0.25
# ('arm', 'what'):0.5
# ('what', 'engag'):0.3333333333333333
# ('engag', 'can'):0.2
# ('can', 'look'):0.08333333333333333
# ('away', 'charact'):0.16666666666666666
# ('studi', 'slowli'):0.1111111111111111
# ('slowli', 'sure'):0.3333333333333333
# ('sure', 'descend'):0.05
# ('descend', 'dark'):1.0
# ('dark', 'uncomfort'):0.024390243902439025
# ('uncomfort', 'place'):0.2
# ('place', 'befit'):0.09090909090909091
# ('befit', 'name'):1.0
# ('name', 'reput'):0.2
# ('reput', 'titl'):1.0
# ('titl', 'may'):0.25
# ('may', 'seem'):0.1
# ('seem', 'far'):0.05555555555555555
# ('far', 'earli'):0.05
# ('earli', 'call'):0.3333333333333333
# ('call', 'one'):0.125
# ('one', 'confid'):0.015384615384615385
# ('confid', 'say'):0.5
# ('say', 'phoenix'):0.024390243902439025
# ('phoenix', 'full'):0.010869565217391304
# ('full', 'embodi'):0.2
# ('embodi', 'fleck'):0.3333333333333333
# ('fleck', 'goe'):0.03225806451612903
# ('goe', 'one'):0.2
# ('one', 'singularli'):0.015384615384615385
# ('singularli', 'impress'):1.0
# ('impress', 'act'):0.25
# ('act', 'turn'):0.023255813953488372
# ('turn', 'decad'):0.1111111111111111
# ('decad', 'time'):0.125
# ('time', 'similar'):0.017241379310344827
# ('similar', 'de'):0.14285714285714285
# ('no', 'train'):0.1111111111111111
# ('train', 'sickl'):0.6
# ('sickl', 'taxi'):0.3333333333333333
# ('driver', 'daniel'):0.043478260869565216
# ('daniel', 'day'):0.3333333333333333
# ('day', 'lewi'):0.14285714285714285
# ('lewi', 'daniel'):0.5
# ('daniel', 'plainview'):0.3333333333333333
# ('plainview', 'blood'):1.0
# ('blood', 'pace'):0.2
# ('pace', 'achiev'):0.16666666666666666
# ('achiev', 'sunni'):0.2
# ('sunni', 'dog'):1.0
# ('dog', 'day'):0.5
# ('day', 'afternoon'):0.14285714285714285
# ('afternoon', 'phoenix'):1.0
# ('phoenix', 'command'):0.010869565217391304
# ('command', 'everi'):1.0
# ('everi', 'second'):0.0625
# ('second', 'screen'):0.3333333333333333
# ('get', 'phillip'):0.019230769230769232
# ('phillip', 'dark'):0.027777777777777776
# ('dark', 'tale'):0.024390243902439025
# ('tale', 'must'):0.25
# ('must', 'sure'):0.16666666666666666
# ('sure', 'biggest'):0.05
# ('biggest', 'sure'):0.5
# ('sure', 'fire'):0.05
# ('fire', 'bet'):0.3333333333333333
# ('bet', 'oscar'):1.0
# ('oscar', 'could'):0.047619047619047616
# ('could', 'ever'):0.08333333333333333
# ('ever', 'hope'):0.043478260869565216
# ('hope', 'get'):0.1
# ('get', 'way'):0.019230769230769232
# ('way', 'fleck'):0.030303030303030304
# ('fleck', 'appear'):0.03225806451612903
# ('appear', 'physic'):0.14285714285714285
# ('physic', 'simpl'):0.14285714285714285
# ('simpl', 'walk'):0.5
# ('walk', 'slight'):0.25
# ('slight', 'facial'):1.0
# ('facial', 'tick'):0.3333333333333333
# ('tick', 'right'):1.0
# ('right', 'hunt'):0.07142857142857142
# ('hunt', 'hard'):0.25
# ('hard', 'forget'):0.16666666666666666
# ('forget', 'collect'):0.3333333333333333
# ('collect', 'hunt'):1.0
# ('hunt', 'laugh'):0.25
# ('laugh', 'phoenix'):0.1111111111111111
# ('phoenix', 'appear'):0.010869565217391304
# ('appear', 'virtual'):0.14285714285714285
# ('virtual', 'everi'):1.0
# ('everi', 'scene'):0.0625
# ('scene', 'joke'):0.047619047619047616
# ('joke', 'never'):0.006535947712418301
# ('never', 'one'):0.045454545454545456
# ('one', 'fail'):0.015384615384615385
# ('fail', 'enthral'):0.2
# ('enthral', 'manag'):0.5
# ('manag', 'seemingli'):0.2
# ('seemingli', 'imposs'):0.5
# ('imposs', 'allow'):0.25
# ('allow', 'u'):0.16666666666666666
# ('u', 'understand'):0.058823529411764705
# ('understand', 'deepli'):0.09090909090909091
# ('deepli', 'flow'):0.14285714285714285
# ('flow', 'deprav'):0.25
# ('deprav', 'creatur'):1.0
# ('creatur', 'creatur'):0.5
# ('creatur', 'begin'):0.5
# ('begin', 'understand'):0.16666666666666666
# ('time', 'even'):0.017241379310344827
# ('even', 'feel'):0.05714285714285714
# ('feel', 'sympathi'):0.03773584905660377
# ('sympathi', 'toward'):0.3333333333333333
# ('toward', 'great'):0.14285714285714285
# ('great', 'inclin'):0.024390243902439025
# ('inclin', 'charact'):1.0
# ('charact', 'hard'):0.014492753623188406
# ('hard', 'think'):0.16666666666666666
# ('think', 'better'):0.02631578947368421
# ('better', 'way'):0.05555555555555555
# ('joke', 'could'):0.006535947712418301
# ('could', 'born'):0.041666666666666664
# ('born', 'exist'):0.5
# ('exist', 'bring'):0.14285714285714285
# ('bring', 'flavour'):0.08333333333333333
# ('flavour', 'glanc'):1.0
# ('glanc', 'fleck'):0.5
# ('fleck', 'there'):0.03225806451612903
# ('there', 'point'):0.08333333333333333
# ('point', 'compar'):0.05555555555555555
# ('compar', 'phoenix'):0.25
# ('phoenix', 'heath'):0.010869565217391304
# ('ledger', 'iron'):0.058823529411764705
# ('iron', 'take'):0.1
# ('take', 'face'):0.037037037037037035
# ('face', 'paint'):0.1111111111111111
# ('paint', 'mad'):0.2
# ('mad', 'man'):0.07692307692307693
# ('man', 'take'):0.041666666666666664
# ('take', 'whole'):0.037037037037037035
# ('whole', 'differ'):0.125
# ('differ', 'beast'):0.058823529411764705
# ('beast', 'entir'):0.5
# ('entir', 'good'):0.2
# ('good', 'phoenix'):0.0196078431372549
# ('phoenix', 'would'):0.010869565217391304
# ('would', 'taken'):0.02857142857142857
# ('taken', 'film'):0.25
# ('far', 'phillip'):0.05
# ('phillip', 'team'):0.027777777777777776
# ('team', 'come'):1.0
# ('come', 'parti'):0.05263157894736842
# ('parti', 'rel'):1.0
# ('rel', 'small'):0.5
# ('small', 'budget'):1.0
# ('budget', 'film'):1.0
# ('film', 'joke'):0.024691358024691357
# ('joke', 'astound'):0.006535947712418301
# ('astound', 'overal'):0.25
# ('overal', 'qualiti'):0.09090909090909091
# ('qualiti', 'ensur'):0.2
# ('ensur', 'comfort'):1.0
# ('comfort', 'sit'):0.3333333333333333
# ('sit', 'top'):0.3333333333333333
# ('top', 'class'):0.5
# ('class', '2019'):0.09090909090909091
# ('2019', 'film'):0.14285714285714285
# ('film', 'amaz'):0.018518518518518517
# ('amaz', 'think'):0.06666666666666667
# ('think', 'film'):0.07894736842105263
# ('film', 'man'):0.006172839506172839
# ('man', 'gave'):0.041666666666666664
# ('u', 'old'):0.058823529411764705
# ('school', 'hanov'):0.3333333333333333
# ('hanov', 'joke'):0.2
# ('joke', 'see'):0.013071895424836602
# ('see', 'phillip'):0.024390243902439025
# ('phillip', 'grow'):0.027777777777777776
# ('grow', 'whole'):0.3333333333333333
# ('whole', 'new'):0.125
# ('new', 'level'):0.07142857142857142
# ('level', 'point'):0.2
# ('point', 'direct'):0.05555555555555555
# ('direct', 'fit'):0.06666666666666667
# ('fit', 'perfectli'):0.2857142857142857
# ('perfectli', 'lawrenc'):0.1111111111111111
# ('her', 'eyecaptur'):0.5
# ('eyecaptur', 'wa'):1.0
# ('wa', 'like'):0.14285714285714285
# ('like', 'cinematographi'):0.017241379310344827
# ('cinematographi', 'holder'):0.037037037037037035
# ('holder', 'guðnadóttir'):0.6666666666666666
# ('guðnadóttir', 'memor'):0.5
# ('memor', 'score'):0.25
# ('score', 'give'):0.038461538461538464
# ('give', 'joke'):0.037037037037037035
# ('joke', 'epic'):0.006535947712418301
# ('epic', 'unforgett'):1.0
# ('unforgett', 'cinemat'):0.5
# ('cinemat', 'nerv'):0.14285714285714285
# ('nerv', 'bring'):1.0
# ('bring', 'game'):0.08333333333333333
# ('game', 'match'):0.3333333333333333
# ('match', 'captiv'):0.3333333333333333
# ('captiv', 'lead'):1.0
# ('man', 'first'):0.041666666666666664
# ('first', 'foremost'):0.0625
# ('foremost', 'believ'):1.0
# ('believ', 'tale'):0.09090909090909091
# ('tale', 'man'):0.25
# ('man', 'push'):0.041666666666666664
# ('push', 'edg'):0.3333333333333333
# ('edg', 'alreadi'):0.16666666666666666
# ('alreadi', 'enter'):0.14285714285714285
# ('enter', 'limit'):0.5
# ('limit', 'joke'):0.5
# ('joke', 'also'):0.006535947712418301
# ('also', 'manag'):0.038461538461538464
# ('manag', 'throw'):0.2
# ('throw', 'number'):1.0
# ('number', 'surpris'):1.0
# ('surpris', 'narr'):0.25
# ('narr', 'comic'):0.5
# ('book', 'throwback'):0.06666666666666667
# ('throwback', 'doubt'):1.0
# ('doubt', 'discus'):0.3333333333333333
# ('discus', 'adnauseam'):0.5
# ('adnauseam', 'richard'):1.0
# ('richard', 'fan'):1.0
# ('fan', 'natur'):0.16666666666666666
# ('natur', 'tie'):0.5
# ('tie', 'togeth'):0.25
# ('togeth', 'fleck'):0.5
# ('fleck', 'stori'):0.03225806451612903
# ('stori', 'much'):0.02631578947368421
# ('much', 'broader'):0.03333333333333333
# ('broader', 'univers'):1.0
# ('univers', 'without'):0.125
# ('without', 'ever'):0.05555555555555555
# ('ever', 'feel'):0.08695652173913043
# ('forc', 'unnatur'):0.16666666666666666
# ('unnatur', 'within'):1.0
# ('within', 'tale'):0.16666666666666666
# ('tale', 'confront'):0.25
# ('confront', 'even'):0.5
# ('even', 'topic'):0.02857142857142857
# ('topic', 'you'):0.3333333333333333
# ('you', 'get'):0.1111111111111111
# ('get', 'regardless'):0.019230769230769232
# ('regardless', 'gene'):1.0
# ('gene', 'final'):0.1111111111111111
# ('final', 'say'):0.2
# ('say', 'bleak'):0.024390243902439025
# ('bleak', 'beauti'):0.25
# ('beauti', 'boundless'):0.14285714285714285
# ('boundless', 'invent'):1.0
# ('invent', 'led'):0.3333333333333333
# ('led', 'joaquin'):0.5
# ('perform', 'age'):0.017241379310344827
# ('age', 'joke'):0.5
# ('joke', 'outstand'):0.006535947712418301
# ('outstand', 'cinemat'):0.3333333333333333
# ('cinemat', 'achiev'):0.14285714285714285
# ('achiev', 'that'):0.2
# ('that', 'sure'):0.0625
# ('sure', 'talk'):0.05
# ('talk', 'year'):0.08333333333333333
# ('year', 'yet'):0.041666666666666664
# ('yet', 'come'):0.14285714285714285
# ('come', '5'):0.05263157894736842
# ('5', 'french'):0.16666666666666666
# ('french', 'fire'):1.0
# ('fire', '5'):0.3333333333333333
# ('5', 'best'):0.16666666666666666
# ('best', 'ever'):0.025
# ('ever', 'perform'):0.043478260869565216
# ('phoenix', 'sad'):0.010869565217391304
# ('sad', 'loneli'):0.14285714285714285
# ('loneli', 'depress'):0.5
# ('depress', 'realitypeoplelif'):0.16666666666666666
# ('realitypeoplelif', 'chang'):1.0
# ('chang', 'person'):0.1111111111111111
# ('person', 'push'):0.06666666666666667
# ...
# ('manner', 'movi'):0.25
# ('movi', 'set'):0.005025125628140704
# ('set', 'good'):0.06666666666666667
# ('good', 'exampl'):0.0196078431372549
# ('exampl', 'other'):0.25
# ('other', 'comic'):0.1
# ('comic', 'base'):0.04
# ('base', 'move'):0.16666666666666666
# ('move', 'neg'):0.022727272727272728
# ('neg', 'charact'):0.5
# ('portray', 'manner'):0.05555555555555555
# ('manner', 'though'):0.25
# ('though', 'know'):0.1
# ('know', 'joke'):0.041666666666666664
# ('good', 'man'):0.0196078431372549
# ('man', 'feel'):0.041666666666666664
# ('bad', 'point'):0.05263157894736842
# ('act', 'done'):0.023255813953488372
# ('done', 'joaquin'):0.09090909090909091
# ('play', 'role'):0.2
# ('amaz', 'lawless'):0.06666666666666667
# ('lawless', 'proper'):0.2
# ('proper', 'justic'):0.2
# ('justic', 'charact'):0.3333333333333333
# ('joke', 'actor'):0.006535947712418301
# ('abl', 'joaquin'):0.14285714285714285
# ('phoenix', 'brilliant'):0.010869565217391304
# ('brilliant', 'method'):0.25
# ('method', 'actor'):0.3333333333333333
# ('actor', 'movi'):0.05555555555555555
# ('movi', 'made'):0.005025125628140704
# ('made', 'see'):0.05555555555555555
# ('theatr', 'to'):0.5
# ('to', 'stream'):0.3333333333333333
# ('stream', 'pp'):1.0
# ('pp', 'sinc'):1.0
# ('sinc', 'joaquin'):0.1
# ('phoenix', 'announc'):0.010869565217391304
# ('announc', 'play'):0.5
# ('play', 'joke'):0.06666666666666667
# ('joke', 'front'):0.006535947712418301
# ('front', 'hope'):0.3333333333333333
# ('hope', 'train'):0.05
# ('train', 'usual'):0.2
# ('usual', 'lead'):0.125
# ('lead', 'disappoint'):0.1111111111111111
# ('disappoint', 'time'):1.0
# ('movi', 'gritti'):0.005025125628140704
# ('gritti', 'realist'):0.125
# ('realist', 'attitud'):0.09090909090909091
# ('attitud', 'toward'):1.0
# ('toward', 'girlfriend'):0.14285714285714285
# ('girlfriend', 'clue'):1.0
# ('clue', 'comic'):1.0
# ('comic', 'batman'):0.04
# ('batman', 'drag'):0.04
# ('drag', 'along'):0.3333333333333333
# ('along', 'ask'):0.16666666666666666
# ('ask', 'base'):0.5
# ('base', 'true'):0.16666666666666666
# ('true', 'stori'):0.14285714285714285
# ('stori', 'ye'):0.02631578947368421
# ('ye', 'similar'):0.16666666666666666
# ('driver', 'fight'):0.043478260869565216
# ('club', 'king'):0.5
# ('comedi', 'obviou'):0.07692307692307693
# ('obviou', 'doesn'):0.5
# ('doesn', 'hurt'):0.07692307692307693
# ('hurt', 'movi'):0.3333333333333333
# ('movi', 'thing'):0.005025125628140704
# ('thing', 'might'):0.043478260869565216
# ('might', 'see'):0.07142857142857142
# ('see', 'come'):0.024390243902439025
# ('come', 'usual'):0.05263157894736842
# ('usual', 'hate'):0.125
# ('movi', 'manag'):0.005025125628140704
# ('manag', 'leav'):0.2
# ('leav', 'question'):0.125
# ('question', 'open'):0.16666666666666666
# ('open', 'answer'):0.25
# ('answer', 'enjoy'):0.5
# ('enjoy', 'doesn'):0.07692307692307693
# ('doesn', 'end'):0.07692307692307693
# ('end', 'movi'):0.09090909090909091
# ('movi', 'finish'):0.005025125628140704
# ('finish', 'debat'):0.3333333333333333
# ('debat', 'theori'):1.0
# ('theori', 'hour'):1.0
# ('hour', 'keep'):0.2
# ('keep', 'review'):0.1111111111111111
# ('review', 'alway'):0.043478260869565216
# ('alway', 'spoil'):0.16666666666666666
# ('spoil', 'free'):1.0
# ('free', 'anna'):0.3333333333333333
# ('anna', 'mention'):1.0
# ('mention', 'see'):0.25
# ('see', 'tri'):0.024390243902439025
# ('tri', 'told'):0.08333333333333333
# ('movi', 'sequel'):0.005025125628140704
# ('sequel', 'watch'):1.0
# ('watch', 'you'):0.023255813953488372
# ('you', 'understand'):0.1111111111111111
# ('understand', 'love'):0.09090909090909091
# ('love', 'charact'):0.05263157894736842
# ('studi', 'instant'):0.1111111111111111
# ('instant', 'classic'):1.0
# ('classic', 'never'):0.16666666666666666
# ('never', 'get'):0.045454545454545456
# ('get', 'old'):0.019230769230769232
# ('old', '11'):0.3333333333333333
# ('11', 'year'):0.5
# ('year', 'heath'):0.041666666666666664
# ('ledger', 'might'):0.058823529411764705
# ('might', 'next'):0.07142857142857142
# ('next', 'joke'):0.2
# ('joke', 'walk'):0.006535947712418301
# ('walk', 'away'):0.25
# ('away', 'littl'):0.16666666666666666
# ('littl', 'golden'):0.1111111111111111
# ('golden', 'man'):1.0
# ('man', 'least'):0.041666666666666664
# ('least', 'nomin'):0.08333333333333333
# ('nomin', 'seem'):0.125
# ('seem', 'guarante'):0.05555555555555555
# ('guarante', 'can'):1.0
# ('can', 'stress'):0.08333333333333333
# ('stress', 'enough'):1.0
# ('enough', 'much'):0.25
# ('enjoy', 'approach'):0.07692307692307693
# ('approach', 'would'):0.3333333333333333
# ('would', 'love'):0.02857142857142857
# ('love', 'see'):0.05263157894736842
# ('see', 'kind'):0.024390243902439025
# ('kind', 'move'):0.06666666666666667
# ('move', 'comic'):0.022727272727272728
# ('comic', 'adapt'):0.04
# ('adapt', 'realli'):0.25
# ('realli', 'deserv'):0.027777777777777776
# ('deserv', 'kind'):0.0625
# ('kind', 'joke'):0.06666666666666667
# ('joke', 'kind'):0.006535947712418301
# ('kind', 'cri'):0.06666666666666667
# ('cri', 'insid'):0.25
# ('insid', 'gothic'):0.5
# ('gothic', 'horror'):0.06666666666666667
# ('horror', 'director'):0.125
# ('director', 'courier'):0.058823529411764705
# ('courier', 'told'):1.0
# ('phillip', 'gone'):0.027777777777777776
# ('gone', 'martin'):0.3333333333333333
# ('scorses', 'filmographi'):0.25
# ('filmographi', 'rang'):1.0
# ('rang', 'taxi'):0.25
# ('comedi', 'bring'):0.07692307692307693
# ('bring', 'dead'):0.08333333333333333
# ('dead', 'shutter'):0.5
# ('shutter', 'island'):1.0
# ('island', 'robert'):1.0
# ('no', 'appear'):0.1111111111111111
# ('appear', 'chat'):0.14285714285714285
# ('chat', 'show'):1.0
# ('host', 'drive'):0.25
# ('drive', 'home'):0.3333333333333333
# ('home', 'score'):0.3333333333333333
# ('score', 'connect'):0.038461538461538464
# ('connect', 'joke'):0.25
# ('joke', 'deliv'):0.006535947712418301
# ('deliv', 'braveri'):0.125
# ('braveri', 'perform'):1.0
# ('fleck', 'one'):0.03225806451612903
# ('one', 'life'):0.015384615384615385
# ('life', 'lose'):0.043478260869565216
# ('lose', 'unabl'):0.3333333333333333
# ('unabl', 'hold'):1.0
# ('hold', 'job'):0.3333333333333333
# ('job', 'clown'):0.125
# ('clown', 'seven'):0.06666666666666667
# ('seven', 'differ'):0.5
# ('differ', 'kind'):0.058823529411764705
# ('kind', 'medit'):0.06666666666666667
# ('medit', 'still'):0.3333333333333333
# ('still', 'panic'):0.1
# ('panic', 'depress'):1.0
# ('depress', 'set'):0.16666666666666666
# ('set', 'earli'):0.06666666666666667
# ('earli', '1980'):0.3333333333333333
# ('1980', 'gothic'):1.0
# ('citi', 'skewer'):0.07692307692307693
# ('skewer', 'fight'):1.0
# ('fight', 'giant'):0.2
# ('giant', 'rat'):1.0
# ('rat', 'social'):0.3333333333333333
# ('servic', 'fund'):0.25
# ('fund', 'cut'):1.0
# ('cut', 'mean'):0.3333333333333333
# ('mean', 'fleck'):0.07142857142857142
# ('fleck', 'social'):0.03225806451612903
# ('social', 'worker'):0.125
# ('worker', 'even'):0.5
# ('even', 'listen'):0.02857142857142857
# ('listen', 'go'):0.5
# ('go', 'like'):0.0625
# ('like', 'train'):0.017241379310344827
# ('sickl', 'fleck'):0.3333333333333333
# ('fleck', 'snap'):0.03225806451612903
# ('snap', 'reborn'):0.5
# ('reborn', 'joke'):1.0
# ('joke', 'polit'):0.006535947712418301
# ('polit', 'nihilist'):0.25
# ('nihilist', 'slow'):0.3333333333333333
# ('slow', 'burn'):0.1
# ('burn', 'drama'):0.5
# ('drama', 'take'):0.09090909090909091
# ('take', 'aim'):0.037037037037037035
# ('aim', 'wealthi'):0.5
# ('wealthi', 'democrat'):1.0
# ('democrat', 'republican'):1.0
# ('republican', 'politician'):1.0
# ('politician', 'alik'):0.5
# ('alik', 'thoma'):0.5
# ('wayn', 'might'):0.07692307692307693
# ('might', 'paint'):0.07142857142857142
# ('paint', 'tramp'):0.2
# ('tramp', 'rich'):0.3333333333333333
# ('rich', 'tucson'):0.14285714285714285
# ('tucson', 'think'):1.0
# ('think', 'not'):0.02631578947368421
# ('not', 'clown'):0.16666666666666666
# ('clown', 'watch'):0.06666666666666667
# ('watch', 'scene'):0.023255813953488372
# ('scene', 'soul'):0.047619047619047616
# ('soul', 'dress'):0.5
# ('dress', 'tuxedo'):1.0
# ('tuxedo', 'watch'):1.0
# ('watch', 'screen'):0.023255813953488372
# ('screen', 'chain'):0.125
# ('movi', 'comment'):0.005025125628140704
# ('comment', 'desper'):1.0
# ('desper', 'condit'):1.0
# ('condit', 'mani'):0.16666666666666666
# ('peopl', 'face'):0.024390243902439025
# ('face', '1930'):0.1111111111111111
# ('1930', 'depress'):1.0
# ('depress', 'joke'):0.16666666666666666
# ('bold', 'comic'):0.5
# ('comic', 'strip'):0.04
# ('strip', 'adapt'):0.5
# ('adapt', 'low'):0.25
# ('low', 'wastag'):0.25
# ('wastag', 'film'):1.0
# ('film', 'plot'):0.006172839506172839
# ('plot', 'tribut'):0.0625
# ('tribut', 'act'):0.3333333333333333
# ('act', 'score'):0.023255813953488372
# ('score', 'move'):0.038461538461538464
# ('move', 'inspir'):0.022727272727272728
# ('inspir', 'watch'):0.14285714285714285
# ('watch', 'movi'):0.023255813953488372
# ('movi', 'ah'):0.005025125628140704
# ('ah', 'told'):1.0
# ('phillip', 'joaquin'):0.027777777777777776
# ('phoenix', 'boom'):0.010869565217391304
# ('boom', 'theater'):1.0
# ('theater', 'hat'):0.5
# ('hat', 'sir'):1.0
# ('sir', 'whole'):1.0
# ('whole', 'point'):0.125
# ('movi', 'bring'):0.005025125628140704
# ('bring', 'attent'):0.08333333333333333
# ('attent', 'mental'):0.3333333333333333
# ('ill', 'ill'):0.043478260869565216
# ('ill', 'one'):0.043478260869565216
# ('one', 'better'):0.015384615384615385
# ('better', 'name'):0.05555555555555555
# ('name', 'bigger'):0.2
# ('issu', 'mental'):0.2
# ('ill', 'film'):0.043478260869565216
# ('film', 'bare'):0.006172839506172839
# ('bare', 'focus'):0.2
# ('focus', 'lack'):0.3333333333333333
# ('lack', 'qualiti'):0.25
# ('qualiti', 'mental'):0.2
# ('mental', 'healthcar'):0.02631578947368421
# ('healthcar', 'film'):1.0
# ('film', 'complet'):0.006172839506172839
# ('complet', 'discredit'):0.14285714285714285
# ('discredit', 'messag'):1.0
# ('messag', 'one'):0.1111111111111111
# ('one', 'dimens'):0.015384615384615385
# ('dimens', 'deduct'):1.0
# ('deduct', 'world'):0.6666666666666666
# ('world', 'charact'):0.06666666666666667
# ('charact', 'inhabit'):0.014492753623188406
# ('inhabit', 'seem'):1.0
# ('seem', 'gothic'):0.05555555555555555
# ('gothic', 'citizen'):0.06666666666666667
# ('citizen', 'entir'):0.5
# ('entir', 'univers'):0.2
# ('univers', 'matter'):0.125
# ('matter', 'exist'):0.3333333333333333
# ('exist', 'put'):0.14285714285714285
# ('put', 'arthur'):0.07142857142857142
# ('arthur', 'consid'):0.017857142857142856
# ('consid', 'film'):0.125
# ('film', 'isn'):0.006172839506172839
# ('isn', 'told'):0.07692307692307693
# ('told', 'arthur'):0.03571428571428571
# ('perspect', 'blatantli'):0.2
# ('blatantli', 'stupid'):1.0
# ('stupid', 'deduct'):1.0
# ('world', 'reason'):0.06666666666666667
# ('reason', 'peopl'):0.2
# ('like', 'much'):0.017241379310344827
# ('much', 'sad'):0.03333333333333333
# ('sad', 'corpor'):0.14285714285714285
# ('corpor', 'slave'):0.5
# ('slave', 'especi'):1.0
# ('especi', 'youth'):0.16666666666666666
# ('youth', 'current'):0.5
# ('current', 'indoctrin'):0.5
# ('indoctrin', 'unconsci'):1.0
# ('unconsci', 'trick'):1.0
# ('believ', 'part'):0.09090909090909091
# ('part', 'bigger'):0.1
# ('bigger', 'caus'):0.3333333333333333
# ('caus', 'realli'):0.125
# ('realli', 'sit'):0.027777777777777776
# ('sit', 'come'):0.3333333333333333
# ('come', 'chair'):0.05263157894736842
# ('chair', 'joke'):1.0
# ('seen', '2019'):0.04
# ('2019', 'act'):0.14285714285714285
# ('act', 'joaquin'):0.023255813953488372
# ('class', 'next'):0.09090909090909091
# ('next', 'level'):0.2
# ('level', 'steal'):0.2
# ('steal', 'show'):1.0
# ('show', 'buri'):0.05555555555555555
# ('buri', 'deeper'):1.0
# ('deeper', 'charact'):1.0
# ('charact', 'much'):0.014492753623188406
# ('much', 'look'):0.03333333333333333
# ('even', 'real'):0.02857142857142857
# ('real', 'joke'):0.05555555555555555
# ('joke', 'itselflmao'):0.006535947712418301
# ('itselflmao', 'seriou'):1.0
# ('seriou', 'ly'):0.25
# ('ly', 'movi'):1.0
# ('also', 'rabi'):0.038461538461538464
# ('rabi', 'question'):1.0
# ('question', 'rebel'):0.16666666666666666
# ('rebel', 'consid'):1.0
# ('consid', 'crime'):0.125
# ('crime', 'watch'):0.14285714285714285
# ('masterpiec', 'least'):0.041666666666666664
# ('least', 'life'):0.08333333333333333
# ('sure', 'chang'):0.05
# ('chang', 'view'):0.1111111111111111
# ('view', 'hero'):0.125
# ('hero', 'villain'):0.1111111111111111
# ('villain', 'villain'):0.05263157894736842
# ('villain', 'born'):0.05263157894736842
# ('born', 'bad'):0.5
# ('bad', 'environ'):0.05263157894736842
# ('environ', 'rais'):1.0
# ('rais', 'make'):0.3333333333333333
# ('make', 'joaquin'):0.017857142857142856
# ('phoenix', 'transform'):0.010869565217391304
# ('transform', 'tubular'):0.2
# ('charact', 'give'):0.014492753623188406
# ('perform', 'worthi'):0.017241379310344827
# ('worthi', 'oscar'):0.2
# ('oscar', 'artist'):0.047619047619047616
# ('artist', 'word'):0.2
# ('use', 'describ'):0.08333333333333333
# ('describ', 'joke'):0.3333333333333333
# ('joke', 'grim'):0.006535947712418301
# ('grim', 'product'):0.3333333333333333
# ('product', 'design'):0.25
# ('design', 'holder'):0.14285714285714285
# ('guðnadóttir', 'abstract'):0.5
# ('abstract', 'score'):1.0
# ('score', 'strong'):0.038461538461538464
# ('strong', 'social'):0.3333333333333333
# ('social', 'messag'):0.125
# ('messag', 'joke'):0.1111111111111111
# ('joke', 'depart'):0.006535947712418301
# ('depart', 'recent'):1.0
# ('recent', 'comicbook'):0.3333333333333333
# ('comicbook', 'move'):0.5
# ('move', 'grim'):0.022727272727272728
# ('grim', 'intens'):0.3333333333333333
# ('intens', 'drama'):0.5
# ('drama', 'homag'):0.09090909090909091
# ('homag', 'scorses'):0.5
# ('scorses', 'lick'):0.25
# ('lick', 'lawless'):0.5
# ('lawless', 'in'):0.2
# ('need', 'freak'):0.05
# ('freak', 'mani'):1.0
# ('mani', 'u'):0.037037037037037035
# ('u', 'play'):0.058823529411764705
# ('role', 'put'):0.07142857142857142
# ('put', 'mask'):0.07142857142857142
# ('mask', 'pretend'):1.0
# ('pretend', 'like'):1.0
# ('like', 'good'):0.017241379310344827
# ('good', 'normal'):0.0196078431372549
# ('normal', 'deep'):1.0
# ('deep', 'insid'):0.16666666666666666
# ('insid', 'joke'):0.5
# ('masterpiec', 'join'):0.041666666666666664
# ('join', 'incred'):0.5
# ('incred', 'dont'):0.06666666666666667
# ('think', 'anyon'):0.02631578947368421
# ('done', 'movi'):0.09090909090909091
# ('movi', 'well'):0.005025125628140704
# ('well', 'he'):0.058823529411764705
# ('he', 'play'):0.14285714285714285
# ('role', 'real'):0.07142857142857142
# ('life', 'outcast'):0.043478260869565216
# ('outcast', 'brazier'):0.3333333333333333
# ('brazier', 'one'):0.3333333333333333
# ('one', 'one'):0.015384615384615385
# ('one', 'abl'):0.015384615384615385
# ('abl', 'adapt'):0.14285714285714285
# ('adapt', 'without'):0.25
# ('without', 'contradict'):0.05555555555555555
# ('contradict', 'condit'):1.0
# ('condit', 'cynic'):0.16666666666666666
# ('cynic', 'violent'):0.5
# ('violent', 'moral'):0.07692307692307693
# ('moral', 'corrupt'):0.25
# ('corrupt', 'time'):0.2
# ('time', 'one'):0.017241379310344827
# ('one', 'react'):0.015384615384615385
# ('react', 'condit'):0.5
# ('condit', 'uncompromis'):0.16666666666666666
# ('uncompromis', 'insan'):1.0
# ('insan', 'fight'):0.125
# ('fight', 'back'):0.2
# ('back', 'use'):0.125
# ('use', 'weapon'):0.08333333333333333
# ('weapon', 'reveng'):1.0
# ('reveng', 'reflect'):1.0
# ('reflect', 'world'):0.5
# ('world', 'mad'):0.06666666666666667
# ('mad', 'insan'):0.07692307692307693
# ('insan', 'grimac'):0.125
# ('grimac', 'disturb'):1.0
# ('disturb', 'question'):0.05263157894736842
# ('question', 'film'):0.16666666666666666
# ('film', 'pose'):0.006172839506172839
# ('pose', 'figur'):1.0
# ('figur', 'joke'):0.5
# ('joke', 'equal'):0.006535947712418301
# ('equal', 'fascin'):0.25
# ('fascin', 'frighten'):1.0
# ('frighten', 'piti'):0.5
# ('piti', 'embodi'):0.5
# ('embodi', 'phoenix'):0.3333333333333333
# ('phoenix', 'unforgett'):0.010869565217391304
# ('unforgett', 'perform'):0.5
# ('perform', 'great'):0.017241379310344827
# ('great', 'depth'):0.024390243902439025
# ('depth', 'wide'):0.2
# ('wide', 'rang'):0.5
# ('emot', 'train'):0.07692307692307693
# ('sickl', 'must'):0.3333333333333333
# ('must', 'centuri'):0.16666666666666666
# ('centuri', 'robert'):0.5
# ('no', 'pay'):0.1111111111111111
# ('pay', 'tribut'):0.3333333333333333
# ('tribut', '43'):0.3333333333333333
# ('43', 'year'):1.0
# ('year', 'later'):0.041666666666666664
# ('later', 'legendari'):0.25
# ('perform', 'taxi'):0.017241379310344827
# ('driver', 'movi'):0.043478260869565216
# ('audienc', 'like'):0.1111111111111111
# ('like', 'joke'):0.017241379310344827
# ('joke', 'hate'):0.006535947712418301
# ('hate', 'thoma'):0.125
# ('wayn', 'batman'):0.07692307692307693
# ('batman', 'father'):0.04
# ('father', 'see'):0.5
# ('see', 'near'):0.024390243902439025
# ('near', 'movi'):0.125
# ('movi', 'go'):0.005025125628140704
# ('go', 'classic'):0.0625
# ('classic', 'hope'):0.16666666666666666

# %%
whole_dataset = ''
index = []
i = 1
for line in df['After Lemmatization']:
  whole_dataset = whole_dataset + line
  value = 'Review-' + str(i)
  index.append(value)
  i += 1

# %%
import nltk
nltk.download('brown')
from textblob import TextBlob
noun_phrases = []
frequency = []
for line in df['After Lemmatization']:
  blob = TextBlob(line)
  for nouns in blob.noun_phrases:
    noun_phrases.append(nouns)
for word in noun_phrases:
  noun_phrases_freq = []
  for line in df['After Lemmatization']:
    noun_phrases_freq.append(line.count(word) / whole_dataset.count(word))
  frequency.append(noun_phrases_freq)
noun_phrases_df = pd.DataFrame(frequency).T
noun_phrases_df.columns = list(noun_phrases)
noun_phrases_df.index = index
noun_phrases_df
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
#             physic pain experi good way  film year review flood wa  \
# Review-1                            0.0                        0.0
# Review-2                            1.0                        0.0
# Review-3                            0.0                        1.0
# Review-4                            0.0                        0.0
# Review-5                            0.0                        0.0
# ...                                 ...                        ...
# Review-121                          0.0                        0.0
# Review-122                          0.0                        0.0
# Review-123                          0.0                        0.0
# Review-124                          0.0                        0.0
# Review-125                          0.0                        0.0
#
#             hope excit movi walk cinema  hollow empti continu  film year  \
# Review-1                            0.0                   0.0        0.0
# Review-2                            0.0                   0.0        0.0
# Review-3                            1.0                   1.0        0.5
# Review-4                            0.0                   0.0        0.0
# Review-5                            0.0                   0.0        0.0
# ...                                 ...                   ...        ...
# Review-121                          0.0                   0.0        0.0
# Review-122                          0.0                   0.0        0.0
# Review-123                          0.0                   0.0        0.0
# Review-124                          0.0                   0.0        0.0
# Review-125                          0.0                   0.0        0.0
#
#             real masterpiec cinematographi excel act  \
# Review-1                                         0.0
# Review-2                                         0.0
# Review-3                                         1.0
# Review-4                                         0.0
# Review-5                                         0.0
# ...                                              ...
# Review-121                                       0.0
# Review-122                                       0.0
# Review-123                                       0.0
# Review-124                                       0.0
# Review-125                                       0.0
#
#             sidecharact bland overlay dramat plot heavili relief plottwist film  \
# Review-1                                                  0.0
# Review-2                                                  0.0
# Review-3                                                  1.0
# Review-4                                                  0.0
# Review-5                                                  0.0
# ...                                                       ...
# Review-121                                                0.0
# Review-122                                                0.0
# Review-123                                                0.0
# Review-124                                                0.0
# Review-125                                                0.0
#
#             harsh actual fall flat  good point  phoenix phenomenon score  ...  \
# Review-1                       0.0         0.0                       0.0  ...
# Review-2                       0.0         0.0                       0.0  ...
# Review-3                       1.0         1.0                       1.0  ...
# Review-4                       0.0         0.0                       0.0  ...
# Review-5                       0.0         0.0                       0.0  ...
# ...                            ...         ...                       ...  ...
# Review-121                     0.0         0.0                       0.0  ...
# Review-122                     0.0         0.0                       0.0  ...
# Review-123                     0.0         0.0                       0.0  ...
# Review-124                     0.0         0.0                       0.0  ...
# Review-125                     0.0         0.0                       0.0  ...
#
#             weapon reveng reflect world  \
# Review-1                            0.0
# Review-2                            0.0
# Review-3                            0.0
# Review-4                            0.0
# Review-5                            0.0
# ...                                 ...
# Review-121                          0.0
# Review-122                          0.0
# Review-123                          0.0
# Review-124                          1.0
# Review-125                          0.0
#
#             mad insan grimac disturb question film pose figur joke  \
# Review-1                                                  0.0
# Review-2                                                  0.0
# Review-3                                                  0.0
# Review-4                                                  0.0
# Review-5                                                  0.0
# ...                                                       ...
# Review-121                                                0.0
# Review-122                                                0.0
# Review-123                                                0.0
# Review-124                                                1.0
# Review-125                                                0.0
#
#             equal fascin frighten piti embodi phoenix unforgett  great depth  \
# Review-1                                                  0.0            0.0
# Review-2                                                  0.0            0.0
# Review-3                                                  0.0            0.0
# Review-4                                                  0.0            0.0
# Review-5                                                  0.0            0.0
# ...                                                       ...            ...
# Review-121                                                0.0            0.0
# Review-122                                                0.0            0.0
# Review-123                                                0.0            0.0
# Review-124                                                1.0            1.0
# Review-125                                                0.0            0.0
#
#             wide rang emot train sickl  centuri robert  taxi driver  \
# Review-1                           0.0             0.0     0.000000
# Review-2                           0.0             0.0     0.000000
# Review-3                           0.0             0.0     0.000000
# Review-4                           0.0             0.0     0.000000
# Review-5                           0.0             0.0     0.043478
# ...                                ...             ...          ...
# Review-121                         0.0             0.0     0.000000
# Review-122                         0.0             0.0     0.000000
# Review-123                         0.0             0.0     0.000000
# Review-124                         1.0             1.0     0.043478
# Review-125                         0.0             0.0     0.000000
#
#             movi audienc  thoma wayn batman father  classic hope
# Review-1             0.0                       0.0           0.0
# Review-2             0.0                       0.0           0.0
# Review-3             0.0                       0.0           0.0
# Review-4             0.0                       0.0           0.0
# Review-5             0.0                       0.0           0.0
# ...                  ...                       ...           ...
# Review-121           0.0                       0.0           0.0
# Review-122           0.0                       0.0           0.0
# Review-123           0.0                       0.0           0.0
# Review-124           0.0                       0.0           0.0
# Review-125           0.5                       1.0           1.0
#
# [125 rows x 1465 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (20 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
# Write your code here
import math
def tf_idf_value(sentence,word):
  size = len(sentence.split(" "))
  tf_value = sentence.count(word)/size
  idf_value = 0
  if(tf_value!=0):
    idf_value = math.log(size)/sentence.count(word)
  else:
    return 0;
  return tf_value*idf_value

sentences = df["Spelling Correction"].values.tolist()
tokens_list = set([j for i in sentences for j in i.split(" ")])
tf_idf = pd.DataFrame(tokens_list,columns=["token"])
count = 0
for i in sentences:
  tf_idf[str(count)] = tf_idf["token"].apply(lambda x : tf_idf_value(i,x))
  count+=1

tf_idf
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#               token    0         1         2         3         4         5  \
# 0                    0.0  0.244136  0.064221  0.055855  0.035297  0.110774
# 1           trilogy  0.0  0.000000  0.000000  0.000000  0.035297  0.000000
# 2        commitment  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 3             jewel  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 4     choreographed  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# ...             ...  ...       ...       ...       ...       ...       ...
# 2865   narcissistic  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2866        tubular  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2867           plot  0.0  0.000000  0.064221  0.000000  0.000000  0.000000
# 2868       whenever  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2869           lost  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
#
#              6         7         8  ...       115      116  117       118  \
# 0     0.058163  0.081918  0.093937  ...  0.035297  0.21799  0.0  0.059398
# 1     0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# 2     0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# 3     0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# 4     0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# ...        ...       ...       ...  ...       ...      ...  ...       ...
# 2865  0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# 2866  0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# 2867  0.000000  0.000000  0.000000  ...  0.035297  0.00000  0.0  0.000000
# 2868  0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# 2869  0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
#
#            119  120       121       122       123       124
# 0     0.079425  0.0  0.099542  0.103716  0.065764  0.180537
# 1     0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 3     0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 4     0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# ...        ...  ...       ...       ...       ...       ...
# 2865  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2866  0.000000  0.0  0.099542  0.000000  0.000000  0.000000
# 2867  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2868  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2869  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
#
# [2870 rows x 126 columns]

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
query_sentence = 'Shang-Chi and the Legend of the Ten Rings is an Action - Fantasy movie in which we watch a new era of Marvel Studios rise with Shang-Chi,the master of Kung Fu. He has to face his past involving him with the Ten Rings organization and crate his future accordingly.Finally, I have to say that "Shang-Chi and the Legend of the Ten Rings" is an amazing movie and I strongly recommend everyone to watch it, especially the fans of Marvel.'
X_list = word_tokenize(query_sentence)
sw = stopwords.words('english') 
X_set = {w for w in X_list if not w in sw}

# %%
def compute_vector(X_set, Y_set):
  rvector = X_set.union(Y_set)
  l1 =[];l2 =[]
  for w in rvector: 
      if w in X_set: l1.append(1)
      else: l1.append(0) 
      if w in Y_set: l2.append(1) 
      else: l2.append(0)
  return rvector, l1, l2

# %%
def compute_cosine(rvector, l1, l2):
  c = 0
  for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
  cosine = c / float((sum(l1)*sum(l2))**0.5) 
  return cosine

# %%
similarity_list = []
for sentence in df['Spelling Correction']:
  Y_list = word_tokenize(sentence)
  Y_set = {w for w in Y_list if not w in sw}
  rvector, l1, l2 = compute_vector(X_set, Y_set)
  try:
    similarity = compute_cosine(rvector, l1, l2)
  except ZeroDivisionError:
    similarity = 'None'
  similarity_list.append(similarity)
cosine_dataframe = pd.DataFrame(list(zip(df['Review'],similarity_list)), columns=['Reviews','Cosine Similarity'])
cosine_dataframe
# Out:
#                                                Reviews Cosine Similarity
# 0                                                                   None
# 1    The movie affects you in a way that makes it p...          0.058124
# 2    When I heard everyone saying that this is the ...          0.091192
# 3    Truly a masterpiece, The Best Hollywood film o...               0.0
# 4    I have seen Joker yesterday at Venice an early...          0.030268
# ..                                                 ...               ...
# 120                                                                 None
# 121  Joaquin Phoenix transforms into the titular ch...               0.0
# 122  And I'm not saying you need to be a freak. Man...          0.030015
# 123  Who is the crazier one? The one who is able to...               0.0
# 124  This is the movie where the audience will like...          0.043937
#
# [125 rows x 2 columns]

# %% [markdown]
# # **Question 3: Create your own word embedding model**

# %% [markdown]
# (20 points). Use the data you collected for assignment two to build a word embedding model:
#
# (1) Train a 300-dimension word embedding (it can be word2vec, glove, ulmfit, bert, or others).
#
# (2) Visualize the word embedding model you created.
#
# Reference: https://machinelearningmastery.com/develop-word-embeddings-python-gensim/
#
# Reference: https://jaketae.github.io/study/word2vec/

# %%
# Write your code here
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:5 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (107.0.5304.87-0ubuntu11.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: selenium in /usr/local/lib/python3.7/dist-packages (4.6.0)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.7/dist-packages (from selenium) (2022.9.24)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.26.12)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.22.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: outcome in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.7/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (4.1.1)

# %%
from selenium import webdriver #importing selenium package
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import time

driver = webdriver.Chrome('chromedriver',options=options)
link = 'https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv'
title_array = []
review_array = []
driver.get(link)
for num in range(4):
  driver.find_element(By.CLASS_NAME,"ipl-load-more__button").click()
  time.sleep(5)
  listOfTitle = driver.find_elements(By.CLASS_NAME, "title")
  listOfReviews = driver.find_elements(By.CLASS_NAME, "text")
for ele, sub_ele in zip(listOfTitle, listOfReviews):
      title_array.append((ele.text).replace('\n',''))
      review_array.append(sub_ele.text)
df = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# Length of data frame is 124
#                                                  Title  \
# 0                             Perfect in every aspect.
# 1    A psychological study, rather than a superhero...
# 2                      Went for a second time to watch
# 3             JUST AMAZING. How does this movie exist.
# 4    Outstanding movie with a haunting performance ...
# ..                                                 ...
# 119  Masterpiece *Movie Of the Year* Best Actor - J...
# 120  The Joker is supposed to be a diabolical maste...
# 121                               Better if didn't saw
# 122                  Why Todd Phillipps Made This Film
# 123  A total letdown ... a hybrid film bordering be...
#
#                                                 Review
# 0    Truly a masterpiece, The Best Hollywood film o...
# 1    I have seen Joker yesterday at Venice an early...
# 2    I get why some people hate this . It's because...
# 3    Let me start off by saying if Joaquin Phoneix ...
# 4    Every once in a while a movie comes, that trul...
# ..                                                 ...
# 119  Wow I honestly gotta tell you, it's one of the...
# 120
# 121  Disturbing. Just got out of the movie. My humo...
# 122  You will notice the far left journalists: the ...
# 123  Ugghhh how could I be so wrong in my assessmen...
#
# [124 rows x 2 columns]

# %%
list2 = []
for i in df.index:
    y = str(df["Review"][i]).split()
    list2.append(y)

# %%
from gensim.models import Word2Vec
model2 = Word2Vec(list2, size = 300)
print(model2)
# Out:
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# Word2Vec(vocab=442, size=300, alpha=0.025)

# %%
words2 = list(model2.wv.vocab)
words2
# Out:
# ['a',
#  'The',
#  'Best',
#  'Hollywood',
#  'film',
#  'of',
#  'one',
#  'the',
#  'films',
#  'And',
#  'truly',
#  'to',
#  'comic',
#  'book',
#  'so',
#  'and',
#  'real',
#  'people',
#  'are',
#  'find',
#  'it',
#  'but',
#  "it's",
#  "It's",
#  'about',
#  'society',
#  'those',
#  'they',
#  'can',
#  'do',
#  'something',
#  'way',
#  'shows',
#  'class',
#  'how',
#  'rich',
#  'others',
#  'around',
#  'them',
#  'is',
#  'not',
#  "that's",
#  'what',
#  'makes',
#  'There',
#  'could',
#  'be',
#  'in',
#  'our',
#  'that',
#  'much',
#  'than',
#  'making',
#  'this',
#  'up',
#  'first',
#  'film.',
#  'A',
#  'I',
#  'have',
#  'seen',
#  'Joker',
#  'at',
#  'an',
#  'We',
#  'had',
#  'some',
#  'with',
#  'lead',
#  'definitely',
#  'was',
#  'worth',
#  'it.',
#  'cinema',
#  'as',
#  'because',
#  'far',
#  'from',
#  'or',
#  'movie,',
#  'most',
#  'genre',
#  'It',
#  'on',
#  'main',
#  'character,',
#  'Joaquin',
#  'Phoenix',
#  'does',
#  'take',
#  'say',
#  'both',
#  'good.',
#  'might',
#  'joker',
#  'while',
#  "Phoenix's",
#  'being',
#  'movie',
#  'superhero',
#  'movies',
#  'Dark',
#  'Knight',
#  'easily',
#  'good',
#  'very',
#  'film,',
#  'cinematography',
#  'cannot',
#  'feel',
#  'too',
#  'his',
#  'King',
#  'also',
#  'somewhat',
#  'am',
#  'see',
#  'more',
#  'by',
#  'Todd',
#  'This',
#  'best',
#  'only',
#  'should',
#  'get',
#  'why',
#  'hate',
#  'message',
#  'think',
#  'you',
#  'need',
#  'for',
#  "Arthur's",
#  'But',
#  'come',
#  'point',
#  'will',
#  'never',
#  'Phillips',
#  'just',
#  'amazing',
#  'enjoy',
#  'without',
#  'me',
#  'start',
#  'off',
#  'saying',
#  'if',
#  "doesn't",
#  'Oscar',
#  'movie.',
#  'Then',
#  'Oscars',
#  'every',
#  'review',
#  'story',
#  'he',
#  'takes',
#  'time',
#  'score',
#  'felt',
#  'like',
#  'Taxi',
#  'Driver',
#  'got',
#  'scenes',
#  'its',
#  'violent',
#  'all',
#  'going',
#  'needs',
#  'Director',
#  'performance',
#  'watch',
#  "won't",
#  'watching',
#  'seriously',
#  '-',
#  'emotions',
#  'same',
#  'time.',
#  'typical',
#  'psychological',
#  'single',
#  'character',
#  'ever',
#  'who',
#  'You',
#  'understand',
#  'character.',
#  'lot',
#  'us',
#  'become',
#  'better',
#  'everyone',
#  'make',
#  'other',
#  'sad',
#  'quite',
#  'win',
#  'u',
#  'really',
#  'acting',
#  '?',
#  '5',
#  'To',
#  'your',
#  'put',
#  'While',
#  "I've",
#  'many',
#  'down',
#  'often',
#  'great',
#  'effects',
#  'They',
#  "don't",
#  'mean',
#  'What',
#  'into',
#  'we',
#  'man',
#  'him',
#  'made',
#  'When',
#  'He',
#  'has',
#  'thought',
#  'Batman',
#  'getting',
#  'deeply',
#  'plot',
#  'talk',
#  'Heath',
#  'portrayal',
#  'Joker,',
#  'fact',
#  "isn't",
#  'no',
#  'DC',
#  'disturbed',
#  'right',
#  'If',
#  'dark',
#  'love',
#  'villain',
#  'bad',
#  'reviews',
#  'hyped',
#  'out',
#  'this,',
#  'actually',
#  'there',
#  'all.',
#  'even',
#  'left',
#  '10',
#  'here',
#  'tell',
#  "can't",
#  'through',
#  '(or',
#  'entire',
#  'then',
#  'you,',
#  'been',
#  'quality',
#  'live',
#  'little',
#  'where',
#  'would',
#  'seem',
#  'new',
#  'last',
#  'high',
#  'back',
#  'look',
#  'society,',
#  'mentally',
#  'ill',
#  'which',
#  'coming',
#  'away',
#  'looking',
#  'feeling',
#  'still',
#  'any',
#  'scene',
#  'these',
#  'times',
#  "wasn't",
#  'own',
#  'completely',
#  'universe',
#  'done',
#  "Don't",
#  'problem',
#  'feels',
#  'someone',
#  'told',
#  "I'm",
#  'trying',
#  'mental',
#  'illness',
#  'long',
#  'were',
#  'music',
#  'boring.',
#  'my',
#  'did',
#  'move',
#  'maybe',
#  'worse',
#  'social',
#  'life.',
#  'world',
#  'acting,',
#  'sound',
#  'script',
#  'deserves',
#  'story.',
#  'iconic',
#  '&',
#  'nothing',
#  'such',
#  'part',
#  '2',
#  'want',
#  'throughout',
#  'In',
#  'though',
#  '10/10',
#  'already',
#  'Good',
#  'when',
#  'despite',
#  'actor',
#  'Not',
#  'sure',
#  'anything',
#  'this.',
#  'kind',
#  'boring',
#  "That's",
#  'their',
#  'wonder',
#  'audience',
#  'him.',
#  'broken',
#  'goes',
#  'him,',
#  'well',
#  'known',
#  'director',
#  "didn't",
#  'all,',
#  'job',
#  'Arthur',
#  'Fleck',
#  'becoming',
#  'Joker.',
#  'worked',
#  'Murray',
#  'show',
#  'That',
#  'rest',
#  'slow',
#  'De',
#  'Niro',
#  'rating',
#  'less',
#  'disturbing',
#  'lacks',
#  'everything',
#  'Gotham',
#  'clown',
#  'role',
#  'Ledger',
#  '"The',
#  'realistic',
#  'know',
#  'New',
#  'unstable',
#  'gets',
#  'sick',
#  'Thomas',
#  'Wayne',
#  'three',
#  'work',
#  'actors',
#  'may',
#  'Just',
#  'world.',
#  'seems',
#  'name',
#  'rather',
#  'drama',
#  'person',
#  'evil',
#  'wants',
#  'enough',
#  'give',
#  'origin',
#  'hour',
#  "there's",
#  'things',
#  'means',
#  'not.',
#  'thing',
#  'films.',
#  'action',
#  'over',
#  'played',
#  'years',
#  'whole',
#  'characters',
#  'it,',
#  'mind',
#  'tries',
#  'For',
#  'Or',
#  'another',
#  'different',
#  'expecting',
#  '...',
#  'looks',
#  'cinematic',
#  'Fleck,',
#  'since',
#  'after',
#  ':',
#  "could've",
#  'horror',
#  "Joker's",
#  'becomes',
#  'wish',
#  'All',
#  'life',
#  'n',
#  'money',
#  'hard',
#  'legendary']

# %%
# fit a 2d PCA model to the vectors
from sklearn.decomposition import PCA

X = model2[model2.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   after removing the cwd from sys.path.

# %%
# create a scatter plot of the projection
import matplotlib.pyplot as plt
plt.figure (figsize = (20,20))
plt.scatter(result[:, 0], result[:, 1])
words = list(model2.wv.vocab)
for i, word in enumerate(words):
	plt.annotate(word, xy=(result[i, 0], result[i, 1]))
plt.show()

# %% [markdown]
# # **Question 4: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file



# Link: https://github.com/sridhar-maddi/Sridhar_INFO5731_FALL2022/blob/main/review.csv
